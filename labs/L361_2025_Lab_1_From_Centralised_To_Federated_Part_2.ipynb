# %% [markdown]
# # 0. Marking and Guidelines
# ---
# ***IMPORTANT***
#
# > The **attendance** and **active participation** in the **lab sessions** is **strongly recommended** and will be considered for grading.
# >
# > Save a copy of this notebook into your Drive before you start
# >
# > Please attempt all the **questions** marked for your **group** (Part II ✅ | Part III/MPhil ✅).
# >
# > Please, provide your answers in a **new cell below the question cell**. You can make as many new cells as you need.
#
# Please submit a `.zip` file, containing both parts, consisting of:
# 1. A text file with a **publicly** visible link to your notebooks in GitHub.
# 2. A **downloaded copy** (`.ipynb`) of your notebooks or your zipped cloned GitHub repo. You may treat these as a report---we will not be re-executing the code you used to produce the answers unless required.
#
#
# Feel free to attempt more in case you find yourself enjoying the material!
# If you have any questions, please ask them to the teaching assistants.
# Are you interested in knowing more about federated learning and related topics? Reach out to the teaching assistants for additional resources and ask more about the current research projects.

# %% [markdown]
# ## Dependencies
# ---

# %%
# `pip` could produce some errors. Do not worry about them.
# The execution has been verified; it's working anyway.
! pip install --quiet --upgrade "pip"
! pip install --quiet matplotlib tqdm seaborn
! pip install git+https://github.com/Iacob-Alexandru-Andrei/flower.git@teaching \
    torch torchvision ray=="2.6.3"
# Out:
# Collecting git+https://github.com/Iacob-Alexandru-Andrei/flower.git@teaching
#   Cloning https://github.com/Iacob-Alexandru-Andrei/flower.git (to revision teaching) to /private/var/folders/wh/jj4l684d741d6zhjwmw8kmlm0000gn/T/pip-req-build-kilj5ral
#   Running command git clone --filter=blob:none --quiet https://github.com/Iacob-Alexandru-Andrei/flower.git /private/var/folders/wh/jj4l684d741d6zhjwmw8kmlm0000gn/T/pip-req-build-kilj5ral
#   Running command git checkout -b teaching --track origin/teaching
#   Switched to a new branch 'teaching'
#   branch 'teaching' set up to track 'origin/teaching'.
#   Resolved https://github.com/Iacob-Alexandru-Andrei/flower.git to commit 1c4fcc1d4a6e8022ddf6f94ebedef1b8e70e0fc4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (2.6.0)
# Requirement already satisfied: torchvision in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (0.21.0)
# Requirement already satisfied: ray==2.6.3 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (2.6.3)
# Requirement already satisfied: click>=7.0 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from ray==2.6.3) (8.1.8)
# Requirement already satisfied: filelock in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from ray==2.6.3) (3.17.0)
# Requirement already satisfied: jsonschema in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from ray==2.6.3) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from ray==2.6.3) (1.1.0)
# Requirement already satisfied: packaging in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from ray==2.6.3) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from ray==2.6.3) (3.20.3)
# Requirement already satisfied: pyyaml in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from ray==2.6.3) (6.0.2)
# Requirement already satisfied: aiosignal in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from ray==2.6.3) (1.3.2)
# Requirement already satisfied: frozenlist in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from ray==2.6.3) (1.5.0)
# Requirement already satisfied: requests in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from ray==2.6.3) (2.32.3)
# Requirement already satisfied: grpcio>=1.42.0 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from ray==2.6.3) (1.70.0)
# Requirement already satisfied: numpy>=1.19.3 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from ray==2.6.3) (1.26.4)
# Requirement already satisfied: cryptography<42.0.0,>=41.0.2 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from flwr==1.7.0) (41.0.7)
# Requirement already satisfied: iterators<0.0.3,>=0.0.2 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from flwr==1.7.0) (0.0.2)
# Requirement already satisfied: pycryptodome<4.0.0,>=3.18.0 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from flwr==1.7.0) (3.21.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from torch) (2025.2.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: cffi>=1.12 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from cryptography<42.0.0,>=41.0.2->flwr==1.7.0) (1.17.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from jsonschema->ray==2.6.3) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from jsonschema->ray==2.6.3) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from jsonschema->ray==2.6.3) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from jsonschema->ray==2.6.3) (0.22.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from requests->ray==2.6.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from requests->ray==2.6.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from requests->ray==2.6.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from requests->ray==2.6.3) (2025.1.31)
# Requirement already satisfied: pycparser in /Users/pavlepadjin/miniforge3/envs/env10/lib/python3.10/site-packages (from cffi>=1.12->cryptography<42.0.0,>=41.0.2->flwr==1.7.0) (2.22)

# %% [markdown]
# ### Imports.

# %%
import sys
from pathlib import Path

# Adjust the project root (the directory that contains labs)
project_root = Path("/Users/pavlepadjin/src/L361-Federated-Learning")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
import random
from pathlib import Path
import tarfile
from typing import Any
from logging import INFO
from collections import defaultdict, OrderedDict
from collections.abc import Sequence, Callable
import numbers

import numpy as np
import torch
from torch import nn
from torch.nn import Module
from torch.utils.data import DataLoader, Dataset
from enum import IntEnum
import flwr
from flwr.server import History, ServerConfig
from flwr.server.strategy import FedAvgM as FedAvg, Strategy
from flwr.common import log, NDArrays, Scalar, Parameters, ndarrays_to_parameters
from flwr.client.client import Client

from labs.common.client_utils import (
    Net,
    load_femnist_dataset,
    get_network_generator_cnn as get_network_generator,
    train_femnist,
    test_femnist,
    save_history,
)


# Add new seeds here for easy autocomplete
class Seeds(IntEnum):
    """Seeds for reproducibility."""

    DEFAULT = 1337


np.random.seed(Seeds.DEFAULT)
random.seed(Seeds.DEFAULT)
torch.manual_seed(Seeds.DEFAULT)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True


PathType = Path | str | None


def get_device() -> str:
    """Get the device (cuda, mps, cpu)."""
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda"
    elif torch.backends.mps.is_available() and torch.backends.mps.is_built():
        device = "mps"
    return device

# %%
home_dir = Path.cwd()
dataset_dir: Path = home_dir / "femnist"
data_dir: Path = dataset_dir / "data"
centralized_partition: Path = dataset_dir / "client_data_mappings" / "centralized"
centralized_mapping: Path = dataset_dir / "client_data_mappings" / "centralized" / "0"
federated_partition: Path = dataset_dir / "client_data_mappings" / "fed_natural"

# Decompress dataset
if not dataset_dir.exists():
    with tarfile.open(home_dir / "femnist.tar.gz", "r:gz") as tar:
        tar.extractall(path=home_dir)
    log(INFO, "Dataset extracted in %s", dataset_dir)

# %% [markdown]
# ## 5. Building a Flower FL client.
# ---

# %% [markdown]
# Our first client abstraction shall be as simple as possible and will require adjustment to match the structure that the flower framework expects. However, it shall be conceptually identical and require only light API changes.

# %% [markdown]
# Moving from centralised ML to server-client FL requires us to provide a means of communication between the respective server and clients. The Flower Framework is ML-framework agnostic and allows various means of transmitting model parameters in the federated network. Since you may have limited resources in these labs, we will only tangentially follow the Flower framework while keeping the computational requirements to a minimum.
#
# The simplest and most common encoding for models is the mere transmission of model parameters as NumPy arrays instead of the stateful PyTorch models. The following functions allow for seamless conversions between the two.

# %%
def set_model_parameters(net: Module, parameters: NDArrays) -> Module:
    """Put a set of parameters into the model object.

    Parameters
    ----------
        net (Module): model object.
        parameters (NDArrays): set of parameters to put into the model.

    Returns
    -------
        Module: updated model object.
    """
    weights = parameters
    params_dict = zip(net.state_dict().keys(), weights, strict=False)
    state_dict = OrderedDict({k: torch.from_numpy(np.copy(v)) for k, v in params_dict})
    net.load_state_dict(state_dict, strict=True)
    return net


def get_model_parameters(net: Module) -> NDArrays:
    """Get the current model parameters as NDArrays.

    Parameters
    ----------
        net (Module): current model object.

    Returns
    -------
        NDArrays: set of parameters from the current model.
    """
    return [val.cpu().numpy() for _, val in net.state_dict().items()]

# %% [markdown]
# With them in place, making the client abstraction compatible with Flower requires only a bit of boilerplate such as allowing NumPy arrays to be received and sent instead of PyTorch models. To achieve this, we provide a model generator capable of creating a network and using the received parameters.
#
# To keep client objects light in the memory when not used by the Flower FL simulator, the model generator is only called as needed for either `fit` or `evaluate`.

# %%
class FlowerRayClient(flwr.client.NumPyClient):
    """Flower client for the FEMNIST dataset."""

    def __init__(
        self,
        cid: int,
        partition_dir: Path,
        model_generator: Callable[[], Module],
    ) -> None:
        """Init the client with its unique id and the folder to load data from.

        Parameters
        ----------
            cid (int): Unique client id for a client used to map it to its data
                partition
            partition_dir (Path): The directory containing data for each
                client/client id
            model_generator (Callable[[], Module]): The model generator function
        """
        self.cid = cid
        log(INFO, "cid: %s", self.cid)
        self.partition_dir = partition_dir
        self.device = str(
            torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        )
        self.model_generator: Callable[[], Module] = model_generator
        self.properties: dict[str, Scalar] = {"tensor_type": "numpy.ndarray"}

    def set_parameters(self, parameters: NDArrays) -> Module:
        """Load weights inside the network.

        Parameters
        ----------
            parameters (NDArrays): set of weights to be loaded.

        Returns
        -------
            [Module]: Network with new set of weights.
        """
        net = self.model_generator()
        return set_model_parameters(net, parameters)

    def get_parameters(self, config: dict[str, Scalar]) -> NDArrays:
        """Return weights from a given model.

        If no model is passed, then a local model is created.
        This can be used to initialise a model in the
        server.
        The config param is not used but is mandatory in Flower.

        Parameters
        ----------
            config (dict[int, Scalar]): dictionary containing configuration info.

        Returns
        -------
            NDArrays: weights from the model.
        """
        net = self.model_generator()
        return get_model_parameters(net)

    def fit(
        self, parameters: NDArrays, config: dict[str, Scalar]
    ) -> tuple[NDArrays, int, dict]:
        """Receive and train a model on the local client data.

        It uses parameters from the config dict

        Parameters
        ----------
            net (NDArrays): Pytorch model parameters
            config (dict[str, Scalar]): dictionary describing the training parameters

        Returns
        -------
            tuple[NDArrays, int, dict]: Returns the updated model, the size of the local
                dataset and other metrics
        """
        # Only create model right before training/testing
        # To lower memory usage when idle
        net = self.set_parameters(parameters)
        net.to(self.device)

        train_loader: DataLoader = self._create_data_loader(config, name="train")
        train_loss = self._train(net, train_loader=train_loader, config=config)
        return get_model_parameters(net), len(train_loader), {"train_loss": train_loss}

    def evaluate(
        self, parameters: NDArrays, config: dict[str, Scalar]
    ) -> tuple[float, int, dict]:
        """Receive and test a model on the local client data.

        It uses parameters from the config dict

        Parameters
        ----------
            net (NDArrays): Pytorch model parameters
            config (dict[str, Scalar]): dictionary describing the testing parameters

        Returns
        -------
            tuple[float, int, dict]: Returns the loss accumulate during testing, the
                size of the local dataset and other metrics such as accuracy
        """
        net = self.set_parameters(parameters)
        net.to(self.device)

        test_loader: DataLoader = self._create_data_loader(config, name="test")
        loss, accuracy = self._test(net, test_loader=test_loader, config=config)
        return loss, len(test_loader), {"local_accuracy": accuracy}

    def _create_data_loader(self, config: dict[str, Scalar], name: str) -> DataLoader:
        """Create the data loader using the specified config parameters.

        Parameters
        ----------
            config (dict[str, Scalar]): dictionary containing dataloader and dataset
                parameters
            mode (str): Load the training or testing set for the client

        Returns
        -------
            DataLoader: A pytorch dataloader iterable for training/testing
        """
        batch_size = int(config["batch_size"])
        num_workers = int(config["num_workers"])
        dataset = self._load_dataset(name)
        return DataLoader(
            dataset=dataset,
            batch_size=batch_size,
            shuffle=True,
            num_workers=num_workers,
            drop_last=(name == "train"),
        )

    def _load_dataset(self, name: str) -> Dataset:
        full_file: Path = self.partition_dir / str(self.cid)
        return load_femnist_dataset(
            mapping=full_file,
            name=name,
            data_dir=data_dir,
        )

    def _train(
        self, net: Module, train_loader: DataLoader, config: dict[str, Scalar]
    ) -> float:
        return train_femnist(
            net=net,
            train_loader=train_loader,
            epochs=int(config["epochs"]),
            device=self.device,
            optimizer=torch.optim.AdamW(
                net.parameters(),
                lr=float(config["client_learning_rate"]),
                weight_decay=float(config["weight_decay"]),
            ),
            criterion=torch.nn.CrossEntropyLoss(),
            max_batches=int(config["max_batches"]),
        )

    def _test(
        self, net: Module, test_loader: DataLoader, config: dict[str, Scalar]
    ) -> tuple[float, float]:
        return test_femnist(
            net=net,
            test_loader=test_loader,
            device=self.device,
            criterion=torch.nn.CrossEntropyLoss(),
            max_batches=int(config["max_batches"]),
        )

    def get_properties(self, config: dict[str, Scalar]) -> dict[str, Scalar]:
        """Return properties for this client.

        Parameters
        ----------
            config (dict[str, Scalar]): Options to be used for selecting specific
            properties.

        Returns
        -------
            dict[str, Scalar]: Returned properties.
        """
        return self.properties

    def get_train_set_size(self) -> int:
        """Return the client train set size.

        Returns
        -------
            int: train set size of the client.
        """
        return len(self._load_dataset("train"))  # type: ignore[reportArgumentType]

    def get_test_set_size(self) -> int:
        """Return the client test set size.

        Returns
        -------
            int: test set size of the client.
        """
        return len(self._load_dataset("test"))  # type: ignore[reportArgumentType]


def fit_client_seeded(
    client: FlowerRayClient,
    params: NDArrays,
    conf: dict[str, Any],
    seed: Seeds = Seeds.DEFAULT,
    **kwargs: Any,
) -> tuple[NDArrays, int, dict]:
    """Wrap to always seed client training."""
    np.random.seed(seed)
    torch.manual_seed(seed)
    random.seed(seed)
    return client.fit(params, conf, **kwargs)

# %% [markdown]
# The underlying FL simulator used by Flower is based on [Ray](https://www.ray.io/). It expects each client only to require a client ID for instantiation. Therefore, using the following generator function, we can determine the specific network used for FL together with the FEMNIST partition to which the `cid` refers.
#
# While we will not use `Ray` in this lab due to its heavyweight nature, we will keep all code API compatible with the default flower framework.

# %%
def get_flower_client_generator(
    model_generator: Callable[[], Module],
    partition_dir: Path,
    mapping_fn: Callable[[int], int] | None = None,
) -> Callable[[str], FlowerRayClient]:
    """Wrap the client instance generator.

    This provides the client generator with a model generator function.
    Also, the partition directory must be passed.
    A mapping function could be used for filtering/ordering clients.

    Parameters
    ----------
        model_generator (Callable[[], Module]): model generator function.
        partition_dir (Path): directory containing the partition.
        mapping_fn (Optional[Callable[[int], int]]): function mapping sorted/filtered
            ids to real cid.

    Returns
    -------
        Callable[[str], FlowerRayClient]: client instance.
    """

    def client_fn(cid: str) -> FlowerRayClient:
        """Create a single client instance given the client id `cid`.

        Parameters
        ----------
            cid (str): client id, Flower requires this to be of type str.

        Returns
        -------
            FlowerRayClient: client instance.
        """
        return FlowerRayClient(
            cid=mapping_fn(int(cid)) if mapping_fn is not None else int(cid),
            partition_dir=partition_dir,
            model_generator=model_generator,
        )

    return client_fn

# %% [markdown]
# To ensure the Flower client behaves the same as our simple demo client, a simple test using the centralised partition we defined earlier should suffice.

# %%
network_generator = get_network_generator()
seed_net: Net = network_generator()
seed_model_params: NDArrays = get_model_parameters(seed_net)

centralized_flower_client_generator: Callable[[str], FlowerRayClient] = (
    get_flower_client_generator(network_generator, centralized_partition)
)
centralized_flower_client = centralized_flower_client_generator(str(0))
# Out:
# INFO flwr 2025-02-06 13:46:57,340 | 2290543087.py:21 | cid: 0

# %%
centralized_train_config: dict[str, Any] = {
    "epochs": 1,
    "batch_size": 32,
    "client_learning_rate": 0.01,
    "weight_decay": 0.001,
    "num_workers": 0,
    "max_batches": 100,
}

test_config: dict[str, Any] = {
    "batch_size": 32,
    "num_workers": 0,
    "max_batches": 100,
}

# Train parameters on the centralised dataset
trained_params, num_examples, train_metrics = fit_client_seeded(
    centralized_flower_client, params=seed_model_params, conf=centralized_train_config
)
log(INFO, "Train Metrics = %s", train_metrics)
# Out:
# INFO flwr 2025-02-06 13:47:14,521 | 4024557794.py:20 | Train Metrics = {'train_loss': 0.11729415073990822}

# %%
# Test trained parameters on the centralised dataset
loss, num_examples, test_metrics = centralized_flower_client.evaluate(
    parameters=trained_params, config=test_config
)
log(INFO, "Loss = %s; Test Metrics = %s", loss, test_metrics)
# Out:
#   4%|▍         | 100/2329 [00:01<00:43, 51.77it/s]
# INFO flwr 2025-02-06 11:30:38,981 | 592755603.py:5 | Loss = 370.12767148017883; Test Metrics = {'local_accuracy': 0.059375}

# %% [markdown]
# ## 6. FL with natural partitions
# ---

# %% [markdown]
# Given its naturally-partitioned nature, we can easily construct a realistic FL experiment by mapping clients one-to-one with the writers of the original symbols.
#
# To pursue this aim, we shall use the “naturally federated” partition instead of the "centralised” one. We are then using the entire `train.csv` and `test.csv` contained in the subfolders of `client_data_mappings/fed_natural`. Each subfolder is named after the clients' ID in the dataset, i.e., from `0` to `3229`.
#
# To guarantee that each client has sufficient training data to participate meaningfully, a common practice is to set a lower bound on the number of samples a selected client is allowed to have. Generally, this threshold should be equivalent to at least one batch. We will now implement a function to sample clients from the federation that satisfies the abovementioned filter in the train set.

# %%
def sample_random_clients(
    total_clients: int,
    filter_less: int,
    partition: Path,
    seed: int | None = Seeds.DEFAULT,
) -> Sequence[int]:
    """Sample randomly clients.

    A filter on the client train set size is performed.

    Parameters
    ----------
        total_clients (int): total number of clients to sample.
        filter_less (int): max number of train samples for which the client is
            **discarded**.
        partition (Path): path to the folder containing the partitioning.
        seed (Optional[int], optional): seed for the random generator. Defaults to None.

    Returns
    -------
        Sequence[int]: list of sample client ids as int.
    """
    real_federated_cid_client_generator: Callable[[str], FlowerRayClient] = (
        get_flower_client_generator(network_generator, federated_partition)
    )
    if seed is not None:
        random.seed(seed)
    list_of_ids = []
    while len(list_of_ids) < total_clients:
        current_id = random.randint(0, 3229)
        if (
            real_federated_cid_client_generator(str(current_id)).get_train_set_size()
            > filter_less
        ):
            list_of_ids.append(current_id)
    return list_of_ids

# %% [markdown]
# While FEMNIST has more than 3000 clients, our small-scale experiments will not require more than 100 at any point.

# %%
total_clients: int = 100
list_of_ids = sample_random_clients(
    total_clients, centralized_train_config["batch_size"], federated_partition
)

federated_client_generator: Callable[[str], FlowerRayClient] = (
    get_flower_client_generator(
        network_generator, federated_partition, lambda seq_id: list_of_ids[seq_id]
    )
)
# Out:
# INFO flwr 2025-02-06 13:47:14,527 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-06 13:47:14,531 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-06 13:47:14,533 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-06 13:47:14,535 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-06 13:47:14,537 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-06 13:47:14,539 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 13:47:14,542 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 13:47:14,545 | 2290543087.py:21 | cid: 678
# INFO flwr 2025-02-06 13:47:14,548 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-06 13:47:14,550 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-06 13:47:14,552 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-06 13:47:14,553 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 13:47:14,555 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 13:47:14,556 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 13:47:14,559 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-06 13:47:14,561 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-06 13:47:14,564 | 2290543087.py:21 | cid: 839
# INFO flwr 2025-02-06 13:47:14,566 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 13:47:14,568 | 2290543087.py:21 | cid: 2688
# INFO flwr 2025-02-06 13:47:14,570 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 13:47:14,572 | 2290543087.py:21 | cid: 447
# INFO flwr 2025-02-06 13:47:14,575 | 2290543087.py:21 | cid: 1742
# INFO flwr 2025-02-06 13:47:14,577 | 2290543087.py:21 | cid: 2601
# INFO flwr 2025-02-06 13:47:14,580 | 2290543087.py:21 | cid: 1633
# INFO flwr 2025-02-06 13:47:14,582 | 2290543087.py:21 | cid: 267
# INFO flwr 2025-02-06 13:47:14,586 | 2290543087.py:21 | cid: 2070
# INFO flwr 2025-02-06 13:47:14,588 | 2290543087.py:21 | cid: 2863
# %% [markdown]
# Now, to test that the newly partitioned clients can be trained.

# %%
one_epoch_config: dict[str, Any] = {
    "epochs": 1,
    "batch_size": 32,
    "client_learning_rate": 0.01,
    "weight_decay": 0.001,
    "num_workers": 0,
    "max_batches": 100,
}

test_config: dict[str, Any] = {
    "batch_size": 32,
    "num_workers": 0,
    "max_batches": 100,
}

# %%
num_clients = 4
clients = random.sample(list(range(total_clients)), num_clients)

# %%
trained_models = [
    fit_client_seeded(
        federated_client_generator(str(cid)), seed_model_params, one_epoch_config
    )
    for cid in clients
]
# Out:
# INFO flwr 2025-02-06 13:48:33,089 | 2290543087.py:21 | cid: 937
# INFO flwr 2025-02-06 13:48:33,193 | 2290543087.py:21 | cid: 1167
# INFO flwr 2025-02-06 13:48:33,283 | 2290543087.py:21 | cid: 2167
# INFO flwr 2025-02-06 13:48:33,331 | 2290543087.py:21 | cid: 2471

# %%
trained_model_parameters = [model for model, *rest in trained_models]
trained_model_metrics = [rest for _, *rest in trained_models]
log(INFO, "Metrics from trained models are: %s", trained_model_metrics)
# Out:
# INFO flwr 2025-02-06 13:48:35,198 | 756348695.py:3 | Metrics from trained models are: [[8, {'train_loss': 0.12624435313045979}], [7, {'train_loss': 0.12405697043452944}], [4, {'train_loss': 0.12207966856658459}], [4, {'train_loss': 0.12672988697886467}]]

# %% [markdown]
# ---
#
# **Question 5 (Part II ✅ | Part III/MPhil ✅):**
#
# (You need to provide the answer with **code** for this question. Written argumentation is **strongly** recommended.)
#
# If we index the weights of an ML model consecutively, with the assumed architecture being the same, we can visualize it as a single flattened 1-D vector. One, highly imperfect, metric for determining how similar two ML models are is cosine similarity. We can use this metric to compare the models our clients produce are.
#
# 1. Write functions to:
#     - Flatten the `NDArrays` objects into a single 1-D vector.
#     - Compute the cosine similarity of two 1-D vectors based on their inner product and norms.
# 2. Compute a similarity matrix between all client models and plot it.
# 3. What happens to the similarity matrix if you increase the number of local epochs that clients train for to 5 from 1? Why do you think that is?
# >You may want to save the parameters calculated here separately from the deault ones as both sets will be needed in future questions.
#
# ---
#
# **Question 6 (Part III/MPhil ✅):**
#
# (You need to provide the answer with **code** for this question. Written argumentation is **strongly** recommended.)
#
# One reason that cosine similarity is an imperfect metric is because it considers weights from different layers to be equally important to the model in terms of its behavior and performance. We can thus create a slightly more detailed picture by tracking the cosine similarity across layers.
#
# 1. Create a function which computes the pairwise cosine similarity between flattened model layers across clients, i.e. the cosine similarity between the flattened $l_i$ in `client_x` and the flattened $l_i$ in `client_y`.
# 2. Plot the similarity of the models at each layer between the most similar client pair and the most disimilar client pair (as determined by the multi-epoch experiment) using the **one-epoch models**, how do the curves you observe relate to the general cosine similarity you computed for the flattened models.
# 3. What happens to the curves if you increase the number of local epochs to 5? How does this behavior relate to what you observed in the previous exercise ?
# 4. **Optional**: Do you think there is any connection to the underlying architecture? Why? Repeat the above experiments using an MLP such as the one provided by the  `get_network_generator_mlp` in `client_utils` and compare results against the CNN.
#
# ---

# %% [markdown]
# ### Answer 5

# %%
from typing import List

def flatten_params(params: List[np.ndarray]) -> np.ndarray:
    """
    Each client has a list of parameters (np.ndarray), so we first flatten each np.ndarray
    and then concatenate them (without axis parameter so it is flat)
    """
    return np.concatenate([p.flatten() for p in params])

flattened_params = [flatten_params(p) for p in trained_model_parameters]

# %%
def cosine_similarity(a: np.ndarray, b: np.ndarray) -> float:
    """
    Compute cosine similarity -  a dot product of the two vectors divided by the product of their norms.
    """
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

similarity_matrix = np.zeros((len(flattened_params), len(flattened_params)))
n = len(flattened_params)
for i in range(n):
    for j in range(n):
        similarity_matrix[i, j] = cosine_similarity(flattened_params[i], flattened_params[j])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(similarity_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# We can see that all models are very similar to each other, which is to be expected. The diagonal is 1 because the similarity of a model with itself needs to be 1. It is also symmetric (cosine_similarity(a, b) == cosine_similarity(b, a)). The lowest similarity is 0.82.

# %% [markdown]
# Let's see how the similarity matrix changes if we increase the number of local epochs to 5.

# %%
multi_epoch_config: dict[str, Any] = {
    "epochs": 5,
    "batch_size": 32,
    "client_learning_rate": 0.01,
    "weight_decay": 0.001,
    "num_workers": 0,
    "max_batches": 100,
}

test_config: dict[str, Any] = {
    "batch_size": 32,
    "num_workers": 0,
    "max_batches": 100,
}

num_clients = 4
clients = random.sample(list(range(total_clients)), num_clients)

trained_models = [
    fit_client_seeded(
        federated_client_generator(str(cid)), seed_model_params, multi_epoch_config
    )
    for cid in clients
]

trained_model_parameters_5 = [model for model, *rest in trained_models]
trained_model_metrics_5 = [rest for _, *rest in trained_models]
log(INFO, "Metrics from trained models are: %s", trained_model_metrics_5)

flattened_params_5 = [flatten_params(p) for p in trained_model_parameters_5]
similarity_matrix_5 = np.zeros((len(flattened_params_5), len(flattened_params_5)))
n = len(flattened_params_5)
for i in range(n):
    for j in range(n):
        similarity_matrix_5[i, j] = cosine_similarity(flattened_params_5[i], flattened_params_5[j])
# Out:
# INFO flwr 2025-02-06 13:47:44,796 | 2290543087.py:21 | cid: 937
# INFO flwr 2025-02-06 13:47:45,154 | 2290543087.py:21 | cid: 1167
# INFO flwr 2025-02-06 13:47:45,564 | 2290543087.py:21 | cid: 2167
# INFO flwr 2025-02-06 13:47:45,759 | 2290543087.py:21 | cid: 2471
# INFO flwr 2025-02-06 13:47:45,979 | 4190304666.py:28 | Metrics from trained models are: [[8, {'train_loss': 0.11196040734648705}], [7, {'train_loss': 0.10911377945116588}], [4, {'train_loss': 0.11660374887287617}], [4, {'train_loss': 0.10609660297632217}]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(similarity_matrix_5, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# We see that the similarity is much lower. This is a proof of a Federated Learning tradeoff - having more local epochs decreases the communication overhead, but presents the risk of models diverging. These models overfit more to the local data and are synced less often. This can lead to a more noisy and potentially non-converging training.

# %% [markdown]
# ### Answer 6

# %% [markdown]
# First, let's make a layerwise cosine similarity function.

# %%
def cosine_similarity_layerwise(a: List[np.ndarray], b: List[np.ndarray]) -> float:
    """
    Compute cosine similarity layerwise.
    """
    return [cosine_similarity(a[i].flatten(), b[i].flatten()) for i in range(len(a))]

# %% [markdown]
# According to the multi-epoch experiment, the most similar models are 2 and 3, and the most dissimilar are 0 and 1. We will use weights from the one-epoch experiment, as written in the question.

# %%
most_sim_layerwise = cosine_similarity_layerwise(trained_model_parameters[2], trained_model_parameters[3])
most_dissim_layerwise = cosine_similarity_layerwise(trained_model_parameters[0], trained_model_parameters[1])

layers = range(len(most_sim_layerwise))
plt.scatter(layers, most_sim_layerwise, label='Most similar')
plt.plot(layers, most_sim_layerwise, label='Most similar', linestyle='--')

plt.scatter(layers, most_dissim_layerwise, label='Most dissimilar')
plt.plot(layers, most_dissim_layerwise, label='Most dissimilar', linestyle='--')

plt.title('Layerwise cosine similarity on one-epoch experiment for most similar and dissimilar models')
plt.legend()
plt.show()

# %% [markdown]
# We can see that the most similar models ALWAYS have a higher similarity than the most dissimilar models (a.k.a. there is no layer in most dissimilar models that has a higher similarity than the most similar models). This could indicate that the modelwise similarity is a good proxy for the layerwise similarity IN THE CASE of one-epoch training.

# %% [markdown]
# We will do the same plot for the multi-epoch experiment.

# %%
most_sim_layerwise = cosine_similarity_layerwise(trained_model_parameters_5[2], trained_model_parameters_5[3])
most_dissim_layerwise = cosine_similarity_layerwise(trained_model_parameters_5[0], trained_model_parameters_5[1])

layers = range(len(most_sim_layerwise))
plt.scatter(layers, most_sim_layerwise, label='Most similar')
plt.plot(layers, most_sim_layerwise, linestyle='--')

plt.scatter(layers, most_dissim_layerwise, label='Most dissimilar')
plt.plot(layers, most_dissim_layerwise, linestyle='--')

plt.title('Layerwise cosine similarity on multi-epoch experiment for most similar and dissimilar models')
plt.legend()
plt.show()

# %% [markdown]
# We see that in the case of multi-epoch training, there is a situation where the most dissimilar model has a layer with higher similarity than the most similar model. This might indicate a pattern - the lower the similarity, the worse the modelwise similarity is. Layerwise similarity is more informative, as it tells the broader picture.

# %% [markdown]
# **Optional**
#
# Let's repeat the same experiment with an MLP.

# %%
from common.client_utils import get_network_generator_mlp

network_generator_mlp = get_network_generator_mlp()
seed_net_mlp: Net = network_generator_mlp()
seed_model_params_mlp: NDArrays = get_model_parameters(seed_net_mlp)

federated_client_generator_mlp: Callable[[str], FlowerRayClient] = (
    get_flower_client_generator(
        network_generator_mlp, federated_partition, lambda seq_id: list_of_ids[seq_id]
    )
)

trained_models_mlp = [
    fit_client_seeded(
        federated_client_generator_mlp(str(cid)), seed_model_params_mlp, one_epoch_config
    )
    for cid in clients
]

trained_model_parameters_mlp = [model for model, *rest in trained_models_mlp]
trained_model_metrics_mlp = [rest for _, *rest in trained_models_mlp]
log(INFO, "Metrics from trained models are: %s", trained_model_metrics_mlp)
# Out:
# INFO flwr 2025-02-06 19:35:04,659 | 2290543087.py:21 | cid: 937
# INFO flwr 2025-02-06 19:35:05,059 | 2290543087.py:21 | cid: 1167
# INFO flwr 2025-02-06 19:35:05,296 | 2290543087.py:21 | cid: 2167
# INFO flwr 2025-02-06 19:35:05,411 | 2290543087.py:21 | cid: 2471
# INFO flwr 2025-02-06 19:35:05,544 | 722888708.py:22 | Metrics from trained models are: [[8, {'train_loss': 0.4170485073700547}], [7, {'train_loss': 0.3969614707997867}], [4, {'train_loss': 0.5327775850892067}], [4, {'train_loss': 0.5229395031929016}]]

# %%
flattened_params_mlp = [flatten_params(p) for p in trained_model_parameters_mlp]
similarity_matrix_mlp = np.zeros((len(flattened_params_mlp), len(flattened_params_mlp)))
n = len(flattened_params_mlp)
for i in range(n):
    for j in range(n):
        similarity_matrix_mlp[i, j] = cosine_similarity(flattened_params_mlp[i], flattened_params_mlp[j])

import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(similarity_matrix_mlp, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# We can see that with MLP, the standard deviation of similarities is lower. The difference between the most similar and the most dissimilar is only 0.08.

# %%
# now for the multi-epoch experiment
from common.client_utils import get_network_generator_mlp

network_generator_mlp = get_network_generator_mlp()
seed_net_mlp: Net = network_generator_mlp()
seed_model_params_mlp: NDArrays = get_model_parameters(seed_net_mlp)

federated_client_generator_mlp: Callable[[str], FlowerRayClient] = (
    get_flower_client_generator(
        network_generator_mlp, federated_partition, lambda seq_id: list_of_ids[seq_id]
    )
)

trained_models_mlp = [
    fit_client_seeded(
        federated_client_generator_mlp(str(cid)), seed_model_params_mlp, multi_epoch_config
    )
    for cid in clients
]

trained_model_parameters_mlp_5 = [model for model, *rest in trained_models_mlp]
trained_model_metrics_mlp_5 =  [rest for _, *rest in trained_models_mlp]
log(INFO, "Metrics from trained models are: %s", trained_model_metrics_mlp_5)
# Out:
# INFO flwr 2025-02-06 19:36:07,471 | 2290543087.py:21 | cid: 937
# INFO flwr 2025-02-06 19:36:07,947 | 2290543087.py:21 | cid: 1167
# INFO flwr 2025-02-06 19:36:08,349 | 2290543087.py:21 | cid: 2167
# INFO flwr 2025-02-06 19:36:08,602 | 2290543087.py:21 | cid: 2471
# INFO flwr 2025-02-06 19:36:08,855 | 3652092778.py:23 | Metrics from trained models are: [[8, {'train_loss': 0.11445391084998846}], [7, {'train_loss': 0.10887593350240163}], [4, {'train_loss': 0.10676971636712551}], [4, {'train_loss': 0.10639076866209507}]]

# %%
flattened_params_mlp_5 = [flatten_params(p) for p in trained_model_parameters_mlp_5]
similarity_matrix_mlp_5 = np.zeros((len(flattened_params_mlp_5), len(flattened_params_mlp_5)))
n = len(flattened_params_mlp_5)
for i in range(n):
    for j in range(n):
        similarity_matrix_mlp_5[i, j] = cosine_similarity(flattened_params_mlp_5[i], flattened_params_mlp_5[j])



import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(similarity_matrix_mlp_5, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# The pattern mentioned above is even more pronounced with multi epoch. Here, the biggest difference is 0.04.

# %% [markdown]
# ## 7. Federated training with Flower
# ---

# %% [markdown]
# The two basic blocks of synchronous server-client FL systems are:
# - A client with some local training method and data---i.e., SGD. This is what we have built thus far.
# - A server which coordinates training sends the federated model to clients at the start of each round and aggregates model updates at the end of each round.

# %% [markdown]
# ![picture](https://drive.google.com/uc?id=1Db_Uys2QPFHW6cMranZ_QXo2vC0A_C-N)

# %% [markdown]
# While the variety of client local training methods is as wide as ML, server training varies depending on which **aggregation algorithm** combines the model updates and forms the new federated model. Flower refers to the component that controls the aggregation and train/test configuration as a **strategy**. For our labs, strategy and aggregation algorithms will be used interchangeably.
#
# The strategy we shall use is [FedAvg](https://arxiv.org/abs/1602.05629):
#
# $G^{r+1} = G^{r} + \eta \left( \sum_{k=1}^{m} p_k G^r_k \right)$,
#
# where $G^{r+1}$ is the model for the next round, which is formed by applying a model update to the current round model $G^{r}$ weighted by the aggregation learning rate $\eta$. The model update is constructed by a sum of client models $G^{r}_k$ where each client model is weighted by $p_k$. The weight factor is usually set to $p_k = \tfrac{n_k}{N}$---the number of training examples held by said client divided by the example count of each client in the round $N = \sum_{k=1}^{m} n_k$.

# %% [markdown]
# ---
#
# **Question 7 (Part II ✅ | Part III/MPhil ✅):**
#
# (You need to provide the answer with **code** for this question. Written argumentation is **strongly** recommended.)
#
# Averaging models is meant to provide us with a reasonable compromise between the desired models of all clients involved. Given what you already know about the similarity of client models, we can test if this is true.
# 1. Write a function to compute the weighted average of two `NDArrays` objects while preserving the layer-structure. Use the FedAvg equation above with $p_k = \tfrac{n_k}{N}$.
# 2. Compute the average model of the client models above, both the one-epoch and multi-epoch ones.
# 3. Add the averaged models to the cosine-similarity matrices built above, how does it relate to the client models?
#
# ---
#
# **Question 8 (Part III/MPhil ✅):**
#
# (You need to provide the answer with **code** for this question. Written argumentation is **strongly** recommended.)
#
#
# 1. Repeat the procedure above but for layer-wise cosine similarity and plot the cosine similarity of the two clients client most similar and most disimillar to the averaged model (as determined by the five-epoch condition) using the one-epoch models.
# 2. How does the relationship change for the higher-epoch condition?
#
# ---

# %% [markdown]
# ### Answer 7

# %%
def weighted_average(weights_list):
    """
    Perform a weighted average of N model's weights per layer.
    """
    N = len(weights_list)
    p = 1 / N
    n_layers = len(weights_list[0])
    w_avg = [sum([p * weights_list[j][i] for j in range(N)]) for i in range(n_layers)]
    return w_avg

# %%
averaged_weights_one_epoch = weighted_average(trained_model_parameters)
averaged_weights_multi_epoch = weighted_average(trained_model_parameters_5)

# %% [markdown]
# Adding the averaged weights to the similarity matrices

# %%
trained_model_params_with_averaged = [*trained_model_parameters, averaged_weights_one_epoch]
trained_model_params_with_averaged_5 = [*trained_model_parameters_5, averaged_weights_multi_epoch]

flattened_params_with_averaged = [flatten_params(p) for p in trained_model_params_with_averaged]    
flattened_params_with_averaged_5 = [flatten_params(p) for p in trained_model_params_with_averaged_5]

similarity_matrix_with_averaged = np.zeros((len(flattened_params_with_averaged), len(flattened_params_with_averaged)))
n = len(flattened_params_with_averaged)
for i in range(n):
    for j in range(n):
        similarity_matrix_with_averaged[i, j] = cosine_similarity(flattened_params_with_averaged[i], flattened_params_with_averaged[j])

similarity_matrix_with_averaged_5 = np.zeros((len(flattened_params_with_averaged_5), len(flattened_params_with_averaged_5)))
n = len(flattened_params_with_averaged_5)
for i in range(n):
    for j in range(n):
        similarity_matrix_with_averaged_5[i, j] = cosine_similarity(flattened_params_with_averaged_5[i], flattened_params_with_averaged_5[j])

# %%
sns.heatmap(similarity_matrix_with_averaged, annot=True, cmap='coolwarm')
plt.title('Cosine similarity of the models with the averaged model - One epoch')
plt.show()

sns.heatmap(similarity_matrix_with_averaged_5, annot=True, cmap='coolwarm')
plt.title('Cosine similarity of the models with the averaged model - Multi epoch')
plt.show()

# %% [markdown]
# We can see that in both cases the average model is much more similar to all of the other models (compared to their similarity with each other) - this is a good indication that FedAvg is a good aggregation algorithm.

# %% [markdown]
# ### Answer 8
#
# Let's compute the layerwise cosine similarity for the averaged models with the most similar and most dissimilar models.

# %%
most_sim_layerwise = cosine_similarity_layerwise(trained_model_parameters[2], trained_model_parameters[3])
most_dissim_layerwise = cosine_similarity_layerwise(trained_model_parameters[0], trained_model_parameters[1])

avg_one_epoch_layerwise_sim2 = cosine_similarity_layerwise(averaged_weights_one_epoch, trained_model_parameters[2])
avg_one_epoch_layerwise_sim3 = cosine_similarity_layerwise(averaged_weights_one_epoch, trained_model_parameters[3])

avg_one_epoch_layerwise_dissim0 = cosine_similarity_layerwise(averaged_weights_one_epoch, trained_model_parameters[0])
avg_one_epoch_layerwise_dissim1 = cosine_similarity_layerwise(averaged_weights_one_epoch, trained_model_parameters[1])

layers = range(len(most_sim_layerwise))

plt.scatter(layers, avg_one_epoch_layerwise_sim2, label='Similar (2) vs averaged')
plt.plot(layers, avg_one_epoch_layerwise_sim2, linestyle='--')

plt.scatter(layers, avg_one_epoch_layerwise_sim3, label='Similar (3) vs averaged')
plt.plot(layers, avg_one_epoch_layerwise_sim3, linestyle='--')

plt.scatter(layers, most_sim_layerwise, label='Most similar (baseline)')
plt.plot(layers, most_sim_layerwise, linestyle='--')


plt.title('Layerwise cosine similarity on one-epoch experiment for most similar models with each other vs with averaged model')
plt.legend()
plt.show()

# %% [markdown]
# This plot tells the similar story as the modelwise similarity plot - the averaged model is generally more similar to the other models than the two most similar models are to each other. There are layers where it doesn't hold true, but on average the averaged model beats the two most similar models.

# %%
layers = range(len(most_sim_layerwise))

plt.scatter(layers, avg_one_epoch_layerwise_dissim0, label='Dissimilar (0) vs averaged')
plt.plot(layers, avg_one_epoch_layerwise_dissim0, linestyle='--')


plt.scatter(layers, avg_one_epoch_layerwise_dissim1, label='Dissimilar (1) vs averaged')
plt.plot(layers, avg_one_epoch_layerwise_dissim1, linestyle='--')


plt.scatter(layers, most_dissim_layerwise, label='Most dissimilar (baseline)')
plt.plot(layers, most_dissim_layerwise, linestyle='--')

plt.title('Layerwise cosine similarity on one-epoch experiment for most dissimilar models with each other vs with averaged model')
plt.legend()
plt.show()

# %% [markdown]
# This plot is even more convincing - the model averaging can significantly increase the similarity, even for models that are the most dissimilar.

# %% [markdown]
# Let's do the same for the multi-epoch experiment.

# %%
most_sim_layerwise = cosine_similarity_layerwise(trained_model_parameters_5[2], trained_model_parameters_5[3])
most_dissim_layerwise = cosine_similarity_layerwise(trained_model_parameters_5[0], trained_model_parameters_5[1])

avg_multi_epoch_layerwise_sim2 = cosine_similarity_layerwise(averaged_weights_multi_epoch, trained_model_parameters_5[2])
avg_multi_epoch_layerwise_sim3 = cosine_similarity_layerwise(averaged_weights_multi_epoch, trained_model_parameters_5[3])

avg_multi_epoch_layerwise_dissim0 = cosine_similarity_layerwise(averaged_weights_multi_epoch, trained_model_parameters_5[0])
avg_multi_epoch_layerwise_dissim1 = cosine_similarity_layerwise(averaged_weights_multi_epoch, trained_model_parameters_5[1])

layers = range(len(most_sim_layerwise))

plt.scatter(layers, avg_multi_epoch_layerwise_sim2, label='Similar (2) vs averaged')
plt.plot(layers, avg_multi_epoch_layerwise_sim2, linestyle='--')

plt.scatter(layers, avg_multi_epoch_layerwise_sim3, label='Similar (3) vs averaged')
plt.plot(layers, avg_multi_epoch_layerwise_sim3, linestyle='--')

plt.scatter(layers, most_sim_layerwise, label='Most similar (baseline)')
plt.plot(layers, most_sim_layerwise, linestyle='--')


plt.title('Layerwise cosine similarity on multi-epoch experiment for most similar models with each other vs with averaged model')
plt.legend()
plt.show()

# %%
# same for the dissimilar models


plt.scatter(layers, avg_multi_epoch_layerwise_dissim0, label='Dissimilar (0) vs averaged')
plt.plot(layers, avg_multi_epoch_layerwise_dissim0, linestyle='--')

plt.scatter(layers, avg_multi_epoch_layerwise_dissim1, label='Dissimilar (1) vs averaged')
plt.plot(layers, avg_multi_epoch_layerwise_dissim1, linestyle='--')

plt.scatter(layers, most_dissim_layerwise, label='Most dissimilar (baseline)')
plt.plot(layers, most_dissim_layerwise, linestyle='--')


plt.title('Layerwise cosine similarity on multi-epoch experiment for most dissimilar models with each other vs with averaged model')
plt.legend()
plt.show()

# %% [markdown]
# The plots for the multi-epoch experiment are very similar and lead to the same conclusion.

# %% [markdown]
# The pieces necessary for starting an FL simulation are now in play; we need to arrange them to fit the Flower API. First, we shall require a separate federated evaluation function which can be called outside the context of a specific client. It will use the centralised test set to be as simple as possible.

# %%
def get_federated_evaluation_function(
    batch_size: int,
    num_workers: int,
    model_generator: Callable[[], Module],
    criterion: Module,
    max_batches: int,
) -> Callable[[int, NDArrays, dict[str, Any]], tuple[float, dict[str, Scalar]]]:
    """Wrap the external federated evaluation function.

    It provides the external federated evaluation function with some
    parameters for the dataloader, the model generator function, and
    the criterion used in the evaluation.

    Parameters
    ----------
        batch_size (int): batch size of the test set to use.
        num_workers (int): correspond to `num_workers` param in the Dataloader object.
        model_generator (Callable[[], Module]):  model generator function.
        criterion (Module): PyTorch Module containing the criterion for evaluating the
        model.

    Returns
    -------
        Callable[[int, NDArrays, dict[str, Any]], tuple[float, dict[str, Scalar]]]:
            external federated evaluation function.
    """

    def federated_evaluation_function(
        server_round: int,
        parameters: NDArrays,
        fed_eval_config: dict[
            str, Any
        ],  # mandatory argument, even if it's not being used
    ) -> tuple[float, dict[str, Scalar]]:
        """Evaluate federated model on the server.

        It uses the centralized val set for sake of simplicity.

        Parameters
        ----------
            server_round (int): current federated round.
            parameters (NDArrays): current model parameters.
            fed_eval_config (dict[str, Any]): mandatory argument in Flower, can contain
                some configuration info

        Returns
        -------
            tuple[float, dict[str, Scalar]]: evaluation results
        """
        device: str = get_device()
        net: Module = set_model_parameters(model_generator(), parameters)
        net.to(device)

        full_file: Path = centralized_mapping
        dataset: Dataset = load_femnist_dataset(data_dir, full_file, "val")

        valid_loader = DataLoader(
            dataset=dataset,
            batch_size=batch_size,
            shuffle=False,
            num_workers=num_workers,
            drop_last=False,
        )

        loss, acc = test_femnist(
            net=net,
            test_loader=valid_loader,
            device=device,
            criterion=criterion,
            max_batches=max_batches,
        )
        return loss, {"accuracy": acc}

    return federated_evaluation_function


federated_evaluation_function = get_federated_evaluation_function(
    batch_size=test_config["batch_size"],
    num_workers=test_config["num_workers"],
    model_generator=network_generator,
    criterion=nn.CrossEntropyLoss(),
    max_batches=test_config["max_batches"],
)

# %%
def aggregate_weighted_average(metrics: list[tuple[int, dict]]) -> dict:
    """Combine results from multiple clients following training or evaluation.

    Parameters
    ----------
        metrics (list[tuple[int, dict]]): collected clients metrics

    Returns
    -------
        dict: result dictionary containing the aggregate of the metrics passed.
    """
    average_dict: dict = defaultdict(list)
    total_examples: int = 0
    for num_examples, metrics_dict in metrics:
        for key, val in metrics_dict.items():
            if isinstance(val, numbers.Number):
                average_dict[key].append((num_examples, val))
        total_examples += num_examples
    return {
        key: {
            "avg": float(
                sum([num_examples * metric for num_examples, metric in val])
                / float(total_examples)
            ),
            "all": val,
        }
        for key, val in average_dict.items()
    }

# %%
# Federated configuration dictionary
federated_train_config: dict[str, Any] = {
    "epochs": 5,
    "batch_size": 32,
    "client_learning_rate": 0.01,
    "weight_decay": 0.001,
    "num_workers": 0,
    "max_batches": 100,
}

# %% [markdown]
# The only challenge left is the FL simulation itself. In `Flower`, a `Server` object handles this for us by using `Ray` and spawning many heavyweight worker process.
#
# Given the limited-resource scenario in which we find ourselves, we provide you with a slightly modified simulation function which uses a simple thread pool. Feel free to swap it out for the original simulation or replace it with your own implementation if so inclined.
#
# > The server we use is not the default `Flower` server as it returns the model parameters from every single round in a `(round, NDArrays)` tuple.

# %%
def start_seeded_simulation(
    client_fn: Callable[[str], Client],
    num_clients: int,
    config: ServerConfig,
    strategy: Strategy,
    name: str,
    return_all_parameters: bool = False,
    seed: int = Seeds.DEFAULT,
    iteration: int = 0,
) -> tuple[list[tuple[int, NDArrays]], History]:
    """Wrap to seed client selection."""
    np.random.seed(seed ^ iteration)
    torch.manual_seed(seed ^ iteration)
    random.seed(seed ^ iteration)
    parameter_list, hist = flwr.simulation.start_simulation_no_ray(
        client_fn=client_fn,
        num_clients=num_clients,
        client_resources={},
        config=config,
        strategy=strategy,
    )
    save_history(home_dir, hist, name)
    return parameter_list, hist

# %%
num_rounds = 10

num_total_clients = 20

num_evaluate_clients = 0
num_clients_per_round = 5

initial_parameters = ndarrays_to_parameters(seed_model_params)


def run_simulation(
    # How long the FL process runs for:
    num_rounds: int = num_rounds,
    # Number of clients available
    num_total_clients: int = num_total_clients,
    # Number of clients used for train/eval
    num_clients_per_round: int = num_clients_per_round,
    num_evaluate_clients: int = num_evaluate_clients,
    # If less clients are overall available stop FL
    min_available_clients: int = num_total_clients,
    # If less clients are available for fit/eval stop FL
    min_fit_clients: int = num_clients_per_round,
    min_evaluate_clients: int = num_evaluate_clients,
    # Function to test the federated model performance
    # external to a client instantiation
    evaluate_fn: (
        Callable[
            [int, NDArrays, dict[str, Scalar]],
            tuple[float, dict[str, Scalar]] | None,
        ]
        | None
    ) = federated_evaluation_function,
    # Functions to generate a config for client fit/evaluate
    # by-default the same config is shallow-copied to all clients in Flower
    # this version simply uses the configs defined above
    on_fit_config_fn: Callable[
        [int], dict[str, Scalar]
    ] = lambda _x: federated_train_config,
    on_evaluate_config_fn: Callable[[int], dict[str, Scalar]] = lambda _x: test_config,
    # The "Parameters" type is merely a more packed version
    # of numpy array lists, used internally by Flower
    initial_parameters: Parameters = initial_parameters,
    # If this is set to True, aggregation will work even if some clients fail
    accept_failures: bool = False,
    # How to combine the metrics dictionary returned by all clients for fit/eval
    fit_metrics_aggregation_fn: Callable | None = aggregate_weighted_average,
    evaluate_metrics_aggregation_fn: Callable | None = aggregate_weighted_average,
    federated_client_generator: Callable[
        [str], flwr.client.NumPyClient
    ] = federated_client_generator,
    # Aggregation learning rate for FedAvg
    server_learning_rate: float = 1.0,
    server_momentum: float = 0.0,
) -> tuple[list[tuple[int, NDArrays]], History]:
    """Run a federated simulation using Flower."""
    log(INFO, "FL will execute for %s rounds", num_rounds)

    # Percentage of clients used for train/eval
    fraction_fit: float = float(num_clients_per_round) / num_total_clients
    fraction_evaluate: float = float(num_evaluate_clients) / num_total_clients

    strategy = FedAvg(
        fraction_fit=fraction_fit,
        fraction_evaluate=fraction_evaluate,
        min_fit_clients=min_fit_clients,
        min_evaluate_clients=min_evaluate_clients,
        min_available_clients=min_available_clients,
        on_fit_config_fn=on_fit_config_fn,
        on_evaluate_config_fn=on_evaluate_config_fn,
        evaluate_fn=evaluate_fn,
        initial_parameters=initial_parameters,
        accept_failures=accept_failures,
        fit_metrics_aggregation_fn=fit_metrics_aggregation_fn,
        evaluate_metrics_aggregation_fn=evaluate_metrics_aggregation_fn,
        server_learning_rate=server_learning_rate,
        server_momentum=server_momentum,
    )
    # resetting the seed for the random selection of clients
    # this way the list of clients trained is guaranteed to be always the same

    cfg = ServerConfig(num_rounds)

    def simulator_client_generator(cid: str) -> Client:
        return federated_client_generator(cid).to_client()

    parameters_for_each_round, hist = start_seeded_simulation(
        client_fn=simulator_client_generator,
        num_clients=num_total_clients,
        config=cfg,
        strategy=strategy,
        name="fedavg",
        return_all_parameters=True,
        seed=Seeds.DEFAULT,
    )
    return parameters_for_each_round, hist

# %%
parameters_for_each_round, hist = run_simulation()
# Out:
# INFO flwr 2025-02-06 14:31:33,088 | 857703202.py:56 | FL will execute for 10 rounds
# INFO flwr 2025-02-06 14:31:33,102 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# INFO flwr 2025-02-06 14:31:33,107 | server_returns_parameters.py:81 | Initializing global parameters
# INFO flwr 2025-02-06 14:31:33,108 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO flwr 2025-02-06 14:31:33,112 | server_returns_parameters.py:84 | Evaluating initial parameters
#  11%|█         | 100/891 [00:03<00:24, 32.39it/s]
# INFO flwr 2025-02-06 14:31:36,427 | server_returns_parameters.py:87 | initial parameters (loss, other metrics): 413.6842665672302, {'accuracy': 0.0065625}
# INFO flwr 2025-02-06 14:31:36,428 | server_returns_parameters.py:97 | FL starting
# DEBUG flwr 2025-02-06 14:31:36,428 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:31:36,432 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:31:36,433 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-06 14:31:36,433 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:31:36,433 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 14:31:36,434 | 2290543087.py:21 | cid: 2600
# DEBUG flwr 2025-02-06 14:31:38,038 | server_returns_parameters.py:237 | fit_round 1 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 125.07it/s]
# INFO flwr 2025-02-06 14:31:39,282 | server_returns_parameters.py:120 | fit progress: (1, 356.7428734302521, {'accuracy': 0.074375}, 2.8540679159923457)
# INFO flwr 2025-02-06 14:31:39,282 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:31:39,283 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:31:39,284 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:31:39,286 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:31:39,287 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-06 14:31:39,288 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:31:39,289 | 2290543087.py:21 | cid: 2997
# DEBUG flwr 2025-02-06 14:31:40,565 | server_returns_parameters.py:237 | fit_round 2 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 127.50it/s]
# INFO flwr 2025-02-06 14:31:41,776 | server_returns_parameters.py:120 | fit progress: (2, 334.8534495830536, {'accuracy': 0.074375}, 5.347873416001676)
# INFO flwr 2025-02-06 14:31:41,776 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:31:41,777 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:31:41,778 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:31:41,780 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-06 14:31:41,782 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:31:41,785 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:31:41,786 | 2290543087.py:21 | cid: 2907
# DEBUG flwr 2025-02-06 14:31:43,288 | server_returns_parameters.py:237 | fit_round 3 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 110.30it/s]
# INFO flwr 2025-02-06 14:31:44,607 | server_returns_parameters.py:120 | fit progress: (3, 333.87857007980347, {'accuracy': 0.08625}, 8.178977250005119)
# INFO flwr 2025-02-06 14:31:44,607 | server_returns_parameters.py:171 | evaluate_round 3: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:31:44,608 | server_returns_parameters.py:223 | fit_round 4: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:31:44,609 | 2290543087.py:21 | cid: 839
# INFO flwr 2025-02-06 14:31:44,611 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:31:44,612 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:31:44,613 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:31:44,615 | 2290543087.py:21 | cid: 1363
# DEBUG flwr 2025-02-06 14:31:45,943 | server_returns_parameters.py:237 | fit_round 4 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06,
649258), (6, 0.08663864557941754), (3, 0.07543400550882022), (5, 0.0639360450208187), (5, 0.059862743318080905)]}), (6, {'avg': 0.05508590918034315, 'all': [(4, 0.0537415836006403), (3, 0.05490452672044436), (5, 0.047342654317617416), (4, 0.0665789544582367), (4, 0.05475229490548372)]}), (7, {'avg': 0.05270777679979801, 'all': [(4, 0.04863510839641094), (4, 0.0435561528429389), (4, 0.06199878454208374), (4, 0.04677703604102135), (4, 0.06257180217653513)]}), (8, {'avg': 0.045600224357958026, 'all': [(4, 0.04937047325074673), (4, 0.05043443199247122), (5, 0.030546486750245093), (8, 0.05434071784839034), (5, 0.039785607159137724)]}), (9, {'avg': 0.028424634505063294, 'all': [(5, 0.02425570599734783), (4, 0.029726400040090084), (4, 0.02852159272879362), (3, 0.03066883919139703), (4, 0.03055391786620021)]}), (10, {'avg': 0.035003015495560785, 'all': [(6, 0.04434328029553095), (8, 0.03255330352112651), (4, 0.039186266250908375), (5, 0.030969106405973435), (4, 0.026751177851110697)]})]}
# INFO flwr 2025-02-06 14:32:03,092 | app.py:252 | app_fit: metrics_distributed {}
# INFO flwr 2025-02-06 14:32:03,093 | app.py:253 | app_fit: losses_centralized [(0, 413.6842665672302), (1, 356.7428734302521), (2, 334.8534495830536), (3, 333.87857007980347), (4, 323.1938862800598), (5, 287.70788860321045), (6, 263.5303021669388), (7, 243.09216439723969), (8, 232.1481785774231), (9, 228.30632442235947), (10, 228.8087636232376)]
# INFO flwr 2025-02-06 14:32:03,094 | app.py:254 | app_fit: metrics_centralized {'accuracy': [(0, 0.0065625), (1, 0.074375), (2, 0.074375), (3, 0.08625), (4, 0.1440625), (5, 0.2678125), (6, 0.3315625), (7, 0.4121875), (8, 0.42375), (9, 0.4790625), (10, 0.47125)]}

# %%
log(
    INFO,
    "Size of the list with the model parameters: %s",
    len(parameters_for_each_round),
)
# Out:
# INFO flwr 2025-02-06 14:32:03,107 | 1532827960.py:1 | Size of the list with the model parameters: 11

# %% [markdown]
# ---
#
# **Question 9 (Part II ✅ | Part III/MPhil ✅):**
#
# (You must provide the answer with **code** and **plots** for this question. A short written argumentation is recommended.)
#
# Now that an entire FL experiment can be trained, it is worth considering the relationship between the FL model across rounds. If we consider the final model $\theta^N$ obtained after $N$ rounds to be the optimal model $\theta^*$, we can ask how optimization step contributed to reaching $\theta^*$.
#
# 1. Run an FL simulation for at-least 50 rounds.
# 2. Build a function which reconstitutes the update that must have been applied to model $\theta^t$ in order to obtain $\theta^{t+1}$, assume the `server_learning_rate` was 1.0. We shall call this update $g_t$ and treat it as a pseudo-gradient.
# 3. For each round plot the cosine similarity between $g_t$ and the direction of improvement towards $\theta^{*}$ calculated as $\theta^{*} - \theta_t$.
# 4. What do you observe from the plots? Does every update point in the direction of the final model? If not, why do you think that is?
#
# ---
#
# **Question 10 (Part III/MPhil ✅):**
#
# (You must provide the answer with **code** and **plots** for this question. A short written argumentation is recommended.)
#
#  and then for
#
# 1.   Read about server momentum in FL [here](https://arxiv.org/abs/2003.00295) and repeat the previous experiments using `server_learning_rate=1.0` and `server_momentum=0.9`. Discuss how the momentum impacts the direction of optimization.
#
# ---

# %% [markdown]
# ### Answer 9

# %%
num_rounds = 80

num_total_clients = 20
num_evaluate_clients = 0
num_clients_per_round = 5

init_params = ndarrays_to_parameters(seed_model_params)

parameters_for_each_round, hist = run_simulation(num_rounds=num_rounds)

log(
    INFO,
    "Size of the list with the model parameters: %s",
    len(parameters_for_each_round),
)
# Out:
# INFO flwr 2025-02-06 14:37:36,165 | 857703202.py:56 | FL will execute for 80 rounds
# INFO flwr 2025-02-06 14:37:36,169 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=80, round_timeout=None)
# INFO flwr 2025-02-06 14:37:36,170 | server_returns_parameters.py:81 | Initializing global parameters
# INFO flwr 2025-02-06 14:37:36,177 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO flwr 2025-02-06 14:37:36,181 | server_returns_parameters.py:84 | Evaluating initial parameters
#  11%|█         | 100/891 [00:01<00:10, 72.15it/s]
# INFO flwr 2025-02-06 14:37:37,983 | server_returns_parameters.py:87 | initial parameters (loss, other metrics): 413.6842665672302, {'accuracy': 0.0065625}
# INFO flwr 2025-02-06 14:37:37,983 | server_returns_parameters.py:97 | FL starting
# DEBUG flwr 2025-02-06 14:37:37,984 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:37:37,985 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:37:37,986 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:37:37,987 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:37:37,989 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 14:37:37,990 | 2290543087.py:21 | cid: 1571
# DEBUG flwr 2025-02-06 14:37:39,501 | server_returns_parameters.py:237 | fit_round 1 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 113.05it/s]
# INFO flwr 2025-02-06 14:37:40,838 | server_returns_parameters.py:120 | fit progress: (1, 361.21392273902893, {'accuracy': 0.079375}, 2.8550885840086266)
# INFO flwr 2025-02-06 14:37:40,839 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:37:40,840 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:37:40,841 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:37:40,841 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:37:40,843 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-06 14:37:40,844 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:37:40,845 | 2290543087.py:21 | cid: 2997
# DEBUG flwr 2025-02-06 14:37:42,270 | server_returns_parameters.py:237 | fit_round 2 received 5 results and 0 failures
#  11%|█         | 100/891 [00:01<00:08, 97.53it/s]
# INFO flwr 2025-02-06 14:37:43,736 | server_returns_parameters.py:120 | fit progress: (2, 340.9659185409546, {'accuracy': 0.074375}, 5.752635125012603)
# INFO flwr 2025-02-06 14:37:43,736 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:37:43,737 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:37:43,738 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:37:43,739 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-06 14:37:43,739 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:37:43,742 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:37:43,745 | 2290543087.py:21 | cid: 2907
# DEBUG flwr 2025-02-06 14:37:45,398 | server_returns_parameters.py:237 | fit_round 3 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 113.66it/s]
# INFO flwr 2025-02-06 14:37:46,694 | server_returns_parameters.py:120 | fit progress: (3, 346.2572729587555, {'accuracy': 0.070625}, 8.710990250008763)
# INFO flwr 2025-02-06 14:37:46,694 | server_returns_parameters.py:171 | evaluate_round 3: no clients selected, cancel
# DEBUG flwr 2025-02-06 14
received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 103.80it/s]
# INFO flwr 2025-02-06 14:37:58,303 | server_returns_parameters.py:120 | fit progress: (7, 290.806667804718, {'accuracy': 0.2459375}, 20.320738375012297)
# INFO flwr 2025-02-06 14:37:58,304 | server_returns_parameters.py:171 | evaluate_round 7: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:37:58,305 | server_returns_parameters.py:223 | fit_round 8: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:37:58,306 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:37:58,306 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-06 14:37:58,309 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-06 14:37:58,311 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:37:58,312 | 2290543087.py:21 | cid: 839
# DEBUG flwr 2025-02-06 14:38:00,029 | server_returns_parameters.py:237 | fit_round 8 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 111.52it/s]
# INFO flwr 2025-02-06 14:38:01,387 | server_returns_parameters.py:120 | fit progress: (8, 270.42543947696686, {'accuracy': 0.3128125}, 23.404405250010313)
# INFO flwr 2025-02-06 14:38:01,387 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:01,388 | server_returns_parameters.py:223 | fit_round 9: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:01,390 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-06 14:38:01,390 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-06 14:38:01,392 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:38:01,395 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-06 14:38:01,399 | 2290543087.py:21 | cid: 1571
# DEBUG flwr 2025-02-06 14:38:02,636 | server_returns_parameters.py:237 | fit_round 9 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 105.50it/s]
# INFO flwr 2025-02-06 14:38:04,027 | server_returns_parameters.py:120 | fit progress: (9, 264.29793202877045, {'accuracy': 0.360625}, 26.044871250007418)
# INFO flwr 2025-02-06 14:38:04,028 | server_returns_parameters.py:171 | evaluate_round 9: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:04,029 | server_returns_parameters.py:223 | fit_round 10: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:04,030 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-06 14:38:04,032 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-06 14:38:04,036 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:38:04,036 | 2290543087.py:21 | cid: 678
# INFO flwr 2025-02-06 14:38:04,039 | 2290543087.py:21 | cid: 2184
# DEBUG flwr 2025-02-06 14:38:05,732 | server_returns_parameters.py:237 | fit_round 10 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 103.95it/s]
# INFO flwr 2025-02-06 14:38:07,123 | server_returns_parameters.py:120 | fit progress: (10, 263.08803033828735, {'accuracy': 0.3478125}, 29.140816625003936)
# INFO flwr 2025-02-06 14:38:07,124 | server_returns_parameters.py:171 | evaluate_round 10: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:07,124 | server_returns_parameters.py:223 | fit_round 11: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:07,127 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:38:07,128 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-06 14:38:07,131 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:38:07,132 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 14:38:07,135 | 2290543087.py:21 | cid: 839
# DEBUG flwr 2025-02-06 14:38:08,584 | server_returns_parameters.py:237 | fit_round 11 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 111.05it/s]
# INFO flwr 2025-02-06 14:38:09,913 | server_returns_parameters.py:120 | fit progress: (11, 233.1700211763382, {'accuracy': 0.405}, 31.93060183399939)
# INFO flwr 2025-02-06 14:38:09,913 | server_returns_parameters.py:171 | evaluate_round 11: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:09,914 | server_returns_parameters.py:223 | fit_round 12: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:09,915 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-06 14:38:09,918 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-06 14:38:09,919 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-06 14:38:09,920 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-06 14:38:09,920 | 2290543087.py:21 | cid: 2688
# DEBUG flwr 2025-02-06 14:38:11,198 | server_returns_parameters.py:237 | fit_round 12 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 117.06it/s]
# INFO flwr 2025-02-06 14:38:12,495 | server_returns_parameters.py:120 | fit progress: (12, 217.90380412340164, {'accuracy': 0.4734375}, 34.51282941701356)
# INFO flwr 2025-02-06 14:38:12,496 | server_returns_parameters.py:171 | evaluate_round 12: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:12,496 | server_returns_parameters.py:223 | fit_round 13: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:12,498 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:38:12,499 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:38:12,500 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:38:12,501 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-06 14:38:12,502 | 2290543087.py:21 | cid: 839
# DEBUG flwr 2025-02-06 14:38:13,842 | server_returns_parameters.py:237 | fit_round 13 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 118.34it/s]
# INFO flwr 2025-02-06 14:38:15,125 | server_returns_parameters.py:120 | fit progress: (13, 199.87170952558517, {'accuracy': 0.505}, 37.14305408400833)
# INFO flwr 2025-02-06 14:38:15,126 | server_returns_parameters.py:171 | evaluate_round 13: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:15,127 | server_returns_parameters.py:223 | fit_round 14: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:15,127 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-06 14:38:15,128 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-06 14:38:15,131 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-06 14:38:15,132 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 14:38:15,134 | 2290543087.py:21 | cid: 1571
# DEBUG flwr 2025-02-06 14:38:16,628 | server_returns_parameters.py:237 | fit_round 14 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 109.28it/s]
# INFO flwr 2025-02-06 14:38:17,969 | server_returns_parameters.py:120 | fit progress: (14, 203.68298935890198, {'accuracy': 0.5265625}, 39.986455250007566)
# INFO flwr 2025-02-06 14:38:17,969 | server_returns_parameters.py:171 | evaluate_round 14: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:17,970 | server_returns_parameters.py:223 | fit_round 15: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:17,971 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-06 14:38:17,973 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:38:17,974 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-06 14:38:17,978 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-06 14:38:17,978 | 2290543087.py:21 | cid: 2184
# DEBUG flwr 2025-02-06 14:38:19,230 | server_returns_parameters.py:237 | fit_round 15 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 118.25it/s]
# INFO flwr 2025-02-06 14:38:20,512 | server_returns_parameters.py:120 | fit progress: (15, 202.38595008850098, {'accuracy': 0.533125}, 42.529700834013056)
# INFO flwr 2025-02-06 14:38:20,512 | server_returns_parameters.py:171 | evaluate_round 15: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:20,513 | server_returns_parameters.py:223 | fit_round 16: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:20,514 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:38:20,515 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-06 14:38:20,518 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:38:20,522 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:38:20,525 | 2290543087.py:21 | cid: 2184
# DEBUG flwr 2025-02-06 14:38:22,063 | server_returns_parameters.py:237 | fit_round 16 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 112.71it/s]
# INFO flwr 2025-02-06 14:38:23,370 | server_returns_parameters.py:120 | fit progress: (16, 181.16706866025925, {'accuracy': 0.5746875}, 45.38829395901121)
# INFO flwr 2025-02-06 14:38:23,371 | server_returns_parameters.py:171 | evaluate_round 16: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:23,372 | server_returns_parameters.py:223 | fit_round 17: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:23,373 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:38:23,374 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-06 14:38:23,379 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-06 14:38:23,380 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-06 14:38:23,381 | 2290543087.py:21 | cid: 1603
# DEBUG flwr 2025-02-06 14:38:24,883 | server_returns_parameters.py:237 | fit_round 17 received 5 results and 0 failures
#  11%|█         | 100/891 [00:01<00:11, 70.08it/s]
# INFO flwr 2025-02-06 14:38:26,730 | server_returns_parameters.py:120 | fit progress: (17, 181.7712715268135, {'accuracy': 0.575}, 48.74834720900981)
# INFO flwr 2025-02-06 14:38:26,731 | server_returns_parameters.py:171 | evaluate_round 17: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:26,733 | server_returns_parameters.py:223 | fit_round 18: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:26,734 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:38:26,737 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:38:26,738 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-06 14:38:26,739 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:38:26,740 | 2290543087.py:21 | cid: 1494
# DEBUG flwr 2025-02-06 14:38:28,058 | server_returns_parameters.py:237 | fit_round 18 received 5 results and 0 failures
#  11%|█         | 100/891 [00:01<00:08, 98.51it/s]
# INFO flwr 2025-02-06 14:38:29,497 | server_returns_parameters.py:120 | fit progress: (18, 168.22352930903435, {'accuracy': 0.596875}, 51.515154625012656)
# INFO flwr 2025-02-06 14:38:29,498 | server_returns_parameters.py:171 | evaluate_round 18: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:29,499 | server_returns_parameters.py:223 | fit_round 19: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:29,500 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:38:29,501 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-06 14:38:29,503 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:38:29,505 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:38:29,510 | 2290543087.py:21 | cid: 2338
# DEBUG flwr 2025-02-06 14:38:31,018 | server_returns_parameters.py:237 | fit_round 19 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 113.73it/s]
# INFO flwr 2025-02-06 14:38:32,386 | server_returns_parameters.py:120 | fit progress: (19, 175.67174541950226, {'accuracy': 0.588125}, 54.404166874999646)
# INFO flwr 2025-02-06 14:38:32,386 | server_returns_parameters.py:171 | evaluate_round 19: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:32,388 | server_returns_parameters.py:223 | fit_round 20: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:32,389 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-06 14:38:32,392 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:38:32,392 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:38:32,396 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-06 14:38:32,398 | 2290543087.py:21 | cid: 2399
# DEBUG flwr 2025-02-06 14:38:34,033 | server_returns_parameters.py:237 | fit_round 20 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 115.83it/s]
# INFO flwr 2025-02-06 14:38:35,316 | server_returns_parameters.py:120 | fit progress: (20, 162.4712945818901, {'accuracy': 0.604375}, 57.334326500000316)
# INFO flwr 2025-02-06 14:38:35,316 | server_returns_parameters.py:171 | evaluate_round 20: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:35,317 | server_returns_parameters.py:223 | fit_round 21: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:35,319 | 2290543087.py:21 | cid: 678
# INFO flwr 2025-02-06 14:38:35,322 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-06 14:38:35,325 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:38:35,326 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:38:35,327 | 2290543087.py:21 | cid: 1260
# DEBUG flwr 2025-02-06 14:38:36,824 | server_returns_parameters.py:237 | fit_round 21 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 115.69it/s]
# INFO flwr 2025-02-06 14:38:38,107 | server_returns_parameters.py:120 | fit progress: (21, 181.57118183374405, {'accuracy': 0.561875}, 60.125641209000605)
# INFO flwr 2025-02-06 14:38:38,108 | server_returns_parameters.py:171 | evaluate_round 21: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:38,109 | server_returns_parameters.py:223 | fit_round 22: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:38,110 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 14:38:38,111 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-06 14:38:38,114 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-06 14:38:38,117 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-06 14:38:38,124 | 2290543087.py:21 | cid: 2530
# DEBUG flwr 2025-02-06 14:38:39,482 | server_returns_parameters.py:237 | fit_round 22 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 107.16it/s]
# INFO flwr 2025-02-06 14:38:40,853 | server_returns_parameters.py:120 | fit progress: (22, 170.22249603271484, {'accuracy': 0.5984375}, 62.87137791700661)
# INFO flwr 2025-02-06 14:38:40,853 | server_returns_parameters.py:171 | evaluate_round 22: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:40,854 | server_returns_parameters.py:223 | fit_round 23: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:40,855 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:38:40,856 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:38:40,859 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:38:40,862 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-06 14:38:40,863 | 2290543087.py:21 | cid: 1571
# DEBUG flwr 2025-02-06 14:38:42,505 | server_returns_parameters.py:237 | fit_round 23 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06,
received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 117.10it/s]
# INFO flwr 2025-02-06 14:38:54,390 | server_returns_parameters.py:120 | fit progress: (27, 146.6713655591011, {'accuracy': 0.6765625}, 76.40893087501172)
# INFO flwr 2025-02-06 14:38:54,391 | server_returns_parameters.py:171 | evaluate_round 27: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:54,391 | server_returns_parameters.py:223 | fit_round 28: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:54,392 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-06 14:38:54,394 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-06 14:38:54,396 | 2290543087.py:21 | cid: 839
# INFO flwr 2025-02-06 14:38:54,396 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:38:54,397 | 2290543087.py:21 | cid: 2997
# DEBUG flwr 2025-02-06 14:38:55,751 | server_returns_parameters.py:237 | fit_round 28 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 115.92it/s]
# INFO flwr 2025-02-06 14:38:57,053 | server_returns_parameters.py:120 | fit progress: (28, 154.67381924390793, {'accuracy': 0.6165625}, 79.07195033400785)
# INFO flwr 2025-02-06 14:38:57,054 | server_returns_parameters.py:171 | evaluate_round 28: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:57,055 | server_returns_parameters.py:223 | fit_round 29: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:57,056 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-06 14:38:57,056 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-06 14:38:57,062 | 2290543087.py:21 | cid: 678
# INFO flwr 2025-02-06 14:38:57,064 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-06 14:38:57,066 | 2290543087.py:21 | cid: 2184
# DEBUG flwr 2025-02-06 14:38:58,357 | server_returns_parameters.py:237 | fit_round 29 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 116.46it/s]
# INFO flwr 2025-02-06 14:38:59,647 | server_returns_parameters.py:120 | fit progress: (29, 149.00392496585846, {'accuracy': 0.6425}, 81.66605574999994)
# INFO flwr 2025-02-06 14:38:59,647 | server_returns_parameters.py:171 | evaluate_round 29: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:38:59,648 | server_returns_parameters.py:223 | fit_round 30: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:38:59,649 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-06 14:38:59,652 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:38:59,653 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:38:59,654 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-06 14:38:59,657 | 2290543087.py:21 | cid: 3175
# DEBUG flwr 2025-02-06 14:39:01,153 | server_returns_parameters.py:237 | fit_round 30 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 114.26it/s]
# INFO flwr 2025-02-06 14:39:02,464 | server_returns_parameters.py:120 | fit progress: (30, 149.75265938043594, {'accuracy': 0.6603125}, 84.48275104200002)
# INFO flwr 2025-02-06 14:39:02,464 | server_returns_parameters.py:171 | evaluate_round 30: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:39:02,465 | server_returns_parameters.py:223 | fit_round 31: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14
strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:41:03,877 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-06 14:41:03,879 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-06 14:41:03,882 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:41:03,883 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-06 14:41:03,886 | 2290543087.py:21 | cid: 1260
# DEBUG flwr 2025-02-06 14:41:05,571 | server_returns_parameters.py:237 | fit_round 73 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 105.20it/s]
# INFO flwr 2025-02-06 14:41:06,949 | server_returns_parameters.py:120 | fit progress: (73, 175.98849706351757, {'accuracy': 0.6590625}, 208.97140208400378)
# INFO flwr 2025-02-06 14:41:06,950 | server_returns_parameters.py:171 | evaluate_round 73: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:41:06,951 | server_returns_parameters.py:223 | fit_round 74: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:41:06,952 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-06 14:41:06,953 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:41:06,955 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-06 14:41:06,958 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 14:41:06,962 | 2290543087.py:21 | cid: 1473
# DEBUG flwr 2025-02-06 14:41:08,216 | server_returns_parameters.py:237 | fit_round 74 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 119.17it/s]
# INFO flwr 2025-02-06 14:41:09,506 | server_returns_parameters.py:120 | fit progress: (74, 160.4348079264164, {'accuracy': 0.67375}, 211.5277871670114)
# INFO flwr 2025-02-06 14:41:09,506 | server_returns_parameters.py:171 | evaluate_round 74: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:41:09,507 | server_returns_parameters.py:223 | fit_round 75: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:41:09,508 | 2290543087.py:21 | cid: 839
# INFO flwr 2025-02-06 14:41:09,511 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-06 14:41:09,512 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-06 14:41:09,521 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-06 14:41:09,522 | 2290543087.py:21 | cid: 2997
# DEBUG flwr 2025-02-06 14:41:10,877 | server_returns_parameters.py:237 | fit_round 75 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 118.25it/s]
# INFO flwr 2025-02-06 14:41:12,167 | server_returns_parameters.py:120 | fit progress: (75, 183.16383096575737, {'accuracy': 0.6575}, 214.1896611250122)
# INFO flwr 2025-02-06 14:41:12,168 | server_returns_parameters.py:171 | evaluate_round 75: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:41:12,169 | server_returns_parameters.py:223 | fit_round 76: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:41:12,170 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:41:12,173 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:41:12,176 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-06 14:41:12,177 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:41:12,178 | 2290543087.py:21 | cid: 2855
# DEBUG flwr 2025-02-06 14:41:13,516 | server_returns_parameters.py:237 | fit_round 76 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 117.18it/s]
# INFO flwr 2025-02-06 14:41:14,805 | server_returns_parameters.py:120 | fit progress: (76, 167.38550040125847, {'accuracy': 0.6684375}, 216.82752395900025)
# INFO flwr 2025-02-06 14:41:14,806 | server_returns_parameters.py:171 | evaluate_round 76: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:41:14,806 | server_returns_parameters.py:223 | fit_round 77: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:41:14,808 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:41:14,808 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:41:14,809 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-06 14:41:14,812 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-06 14:41:14,814 | 2290543087.py:21 | cid: 1473
# DEBUG flwr 2025-02-06 14:41:16,232 | server_returns_parameters.py:237 | fit_round 77 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 116.11it/s]
# INFO flwr 2025-02-06 14:41:17,514 | server_returns_parameters.py:120 | fit progress: (77, 176.24604710936546, {'accuracy': 0.6196875}, 219.53686000000744)
# INFO flwr 2025-02-06 14:41:17,515 | server_returns_parameters.py:171 | evaluate_round 77: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:41:17,516 | server_returns_parameters.py:223 | fit_round 78: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:41:17,517 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:41:17,518 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:41:17,520 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 14:41:17,521 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-06 14:41:17,523 | 2290543087.py:21 | cid: 3175
# DEBUG flwr 2025-02-06 14:41:18,719 | server_returns_parameters.py:237 | fit_round 78 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 115.59it/s]
# INFO flwr 2025-02-06 14:41:20,032 | server_returns_parameters.py:120 | fit progress: (78, 186.66939836740494, {'accuracy': 0.6825}, 222.05459995901037)
# INFO flwr 2025-02-06 14:41:20,032 | server_returns_parameters.py:171 | evaluate_round 78: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:41:20,033 | server_returns_parameters.py:223 | fit_round 79: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:41:20,035 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-06 14:41:20,036 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-06 14:41:20,038 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-06 14:41:20,041 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:41:20,041 | 2290543087.py:21 | cid: 839
# DEBUG flwr 2025-02-06 14:41:21,411 | server_returns_parameters.py:237 | fit_round 79 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 114.78it/s]
# INFO flwr 2025-02-06 14:41:22,725 | server_returns_parameters.py:120 | fit progress: (79, 187.69554245471954, {'accuracy': 0.66875}, 224.74791291700967)
# INFO flwr 2025-02-06 14:41:22,726 | server_returns_parameters.py:171 | evaluate_round 79: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:41:22,727 | server_returns_parameters.py:223 | fit_round 80: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:41:22,728 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-06 14:41:22,728 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:41:22,730 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 14:41:22,735 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-06 14:41:22,739 | 2290543087.py:21 | cid: 2600
# DEBUG flwr 2025-02-06 14:41:24,067 | server_returns_parameters.py:237 | fit_round 80 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 115.69it/s]
# INFO flwr 2025-02-06 14:41:25,425 | server_returns_parameters.py:120 | fit progress: (80, 189.107302069664, {'accuracy': 0.6165625}, 227.44806237501325)
# INFO flwr 2025-02-06 14:41:25,426 | server_returns_parameters.py:171 | evaluate_round 80: no clients selected, cancel
# INFO flwr 2025-02-06 14:41:25,426 | server_returns_parameters.py:150 | FL finished in 227.4489687919995
# INFO flwr 2025-02-06 14:41:25,427 | app.py:250 | app_fit: losses_distributed []
# INFO flwr 2025-02-06 14:41:25,428 | app.py:251 | app_fit: metrics_distributed_fit {'train_loss': [(1, {'avg': 0.
# INFO flwr 2025-02-06 14:41:25,429 | app.py:254 | app_fit: metrics_centralized {'accuracy': [(0, 0.0065625), (1, 0.079375), (2, 0.074375), (3, 0.070625), (4, 0.065625), (5, 0.126875), (6, 0.1575), (7, 0.2459375), (8, 0.3128125), (9, 0.360625), (10, 0.3478125), (11, 0.405), (12, 0.4734375), (13, 0.505), (14, 0.5265625), (15, 0.533125), (16, 0.5746875), (17, 0.575), (18, 0.596875), (19, 0.588125), (20, 0.604375), (21, 0.561875), (22, 0.5984375), (23, 0.5709375), (24, 0.6196875), (25, 0.635), (26, 0.6421875), (27, 0.6765625), (28, 0.6165625), (29, 0.6425), (30, 0.6603125), (31, 0.6234375), (32, 0.6590625), (33, 0.6678125), (34, 0.5915625), (35, 0.6696875), (36, 0.6196875), (37, 0.6559375), (38, 0.6275), (39, 0.651875), (40, 0.5671875), (41, 0.6796875), (42, 0.6896875), (43, 0.6378125), (44, 0.6815625), (45, 0.63625), (46, 0.645), (47, 0.6134375), (48, 0.674375), (49, 0.6240625), (50, 0.5753125), (51, 0.655), (52, 0.5675), (53, 0.669375), (54, 0.6378125), (55, 0.628125), (56, 0.6709375), (57, 0.621875), (58, 0.624375), (59, 0.6634375), (60, 0.525), (61, 0.678125), (62, 0.680625), (63, 0.7053125), (64, 0.6915625), (65, 0.653125), (66, 0.65375), (67, 0.64125), (68, 0.6890625), (69, 0.61375), (70, 0.666875), (71, 0.65375), (72, 0.6740625), (73, 0.6590625), (74, 0.67375), (75, 0.6575), (76, 0.6684375), (77, 0.6196875), (78, 0.6825), (79, 0.66875), (80, 0.6165625)]}
# INFO flwr 2025-02-06 14:41:25,509 | 14259588.py:11 | Size of the list with the model parameters: 81

# %%
ideal_params = flatten_params(parameters_for_each_round[-1][1])

cos_similarities = [
    cosine_similarity(
        flatten_params(parameters_for_each_round[r+1][1]) - flatten_params(parameters_for_each_round[r][1]),
        ideal_params - flatten_params(parameters_for_each_round[r][1])
    )
    for r, _ in parameters_for_each_round[:-1]
]

# %%
n_rounds = len(parameters_for_each_round)
plt.plot(range(n_rounds - 1), cos_similarities)
plt.xlabel('Round Number')
plt.ylabel('Cosine Similarity')
plt.title('Similarity between the pseudo-gradient $g_t$ and the direction of improvement')
plt.grid(True)
plt.show()

# %% [markdown]
# We can see that as the rounds progress, the pseudo-gradient $g_t$ becomes more correlated with the direction of improvement towards the "ideal" model. That means that in the beggining, the model was probably "wandering" and progressing over the loss function space in the direction that is vastly diferent from the final model. That doesn't mean that the direction was wrong (in fact, I assume that is when the loss value decreases the most), but that direction was not as aligned with the final model. Also, the flat region on the plot probably indicates that the model was slowly progressing in the same direction for a long time, possibly because the learning rate was too low (and a lot of steps were needed).

# %% [markdown]
# ### Answer 10
#
# Let's run the simulation with momentum.

# %%
num_rounds = 80

initial_parameters = ndarrays_to_parameters(seed_model_params)

parameters_for_each_round, hist = run_simulation(num_rounds=num_rounds, server_momentum=0.9)

log(INFO, "Size of the list with the model parameters: %s", len(parameters_for_each_round))
# Out:
# INFO flwr 2025-02-06 14:55:52,749 | 857703202.py:56 | FL will execute for 80 rounds
# INFO flwr 2025-02-06 14:55:52,753 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=80, round_timeout=None)
# INFO flwr 2025-02-06 14:55:52,755 | server_returns_parameters.py:81 | Initializing global parameters
# INFO flwr 2025-02-06 14:55:52,760 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO flwr 2025-02-06 14:55:52,767 | server_returns_parameters.py:84 | Evaluating initial parameters
#  11%|█         | 100/891 [00:01<00:11, 70.34it/s]
# INFO flwr 2025-02-06 14:55:54,617 | server_returns_parameters.py:87 | initial parameters (loss, other metrics): 413.6842665672302, {'accuracy': 0.0065625}
# INFO flwr 2025-02-06 14:55:54,618 | server_returns_parameters.py:97 | FL starting
# DEBUG flwr 2025-02-06 14:55:54,618 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:55:54,620 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:55:54,621 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:55:54,624 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:55:54,625 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 14:55:54,626 | 2290543087.py:21 | cid: 1571
# DEBUG flwr 2025-02-06 14:55:56,005 | server_returns_parameters.py:237 | fit_round 1 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 120.95it/s]
# INFO flwr 2025-02-06 14:55:57,276 | server_returns_parameters.py:120 | fit progress: (1, 363.57272720336914, {'accuracy': 0.074375}, 2.6582293750107056)
# INFO flwr 2025-02-06 14:55:57,276 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:55:57,277 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:55:57,279 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:55:57,279 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:55:57,282 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-06 14:55:57,285 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:55:57,285 | 2290543087.py:21 | cid: 2997
# DEBUG flwr 2025-02-06 14:55:58,592 | server_returns_parameters.py:237 | fit_round 2 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 118.75it/s]
# INFO flwr 2025-02-06 14:55:59,867 | server_returns_parameters.py:120 | fit progress: (2, 513.7231271266937, {'accuracy': 0.070625}, 5.249286999998731)
# INFO flwr 2025-02-06 14:55:59,867 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:55:59,869 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:55:59,869 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:55:59,872 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-06 14:55:59,873 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:55:59,873 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:55:59,879 | 2290543087.py:21 | cid: 2907
# DEBUG flwr 2025-02-06 14:56:01,475 | server_returns_parameters.py:237 | fit_round 3 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06,
received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 120.45it/s]
# INFO flwr 2025-02-06 14:56:34,910 | server_returns_parameters.py:120 | fit progress: (15, 327.8484637737274, {'accuracy': 0.1853125}, 40.293195584003115)
# INFO flwr 2025-02-06 14:56:34,910 | server_returns_parameters.py:171 | evaluate_round 15: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:56:34,911 | server_returns_parameters.py:223 | fit_round 16: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:56:34,912 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:56:34,913 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-06 14:56:34,915 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:56:34,916 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:56:34,918 | 2290543087.py:21 | cid: 2184
# DEBUG flwr 2025-02-06 14:56:36,572 | server_returns_parameters.py:237 | fit_round 16 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 122.92it/s]
# INFO flwr 2025-02-06 14:56:37,805 | server_returns_parameters.py:120 | fit progress: (16, 381.85231351852417, {'accuracy': 0.125}, 43.188204375008354)
# INFO flwr 2025-02-06 14:56:37,805 | server_returns_parameters.py:171 | evaluate_round 16: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:56:37,806 | server_returns_parameters.py:223 | fit_round 17: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:56:37,807 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:56:37,808 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-06 14:56:37,811 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-06 14:56:37,812 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-06 14:56:37,816 | 2290543087.py:21 | cid: 1603
# DEBUG flwr 2025-02-06 14:56:39,213 | server_returns_parameters.py:237 | fit_round 17 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 121.26it/s]
# INFO flwr 2025-02-06 14:56:40,456 | server_returns_parameters.py:120 | fit progress: (17, 353.85835313796997, {'accuracy': 0.11625}, 45.83952545899956)
# INFO flwr 2025-02-06 14:56:40,457 | server_returns_parameters.py:171 | evaluate_round 17: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:56:40,458 | server_returns_parameters.py:223 | fit_round 18: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:56:40,458 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:56:40,459 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:56:40,462 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-06 14:56:40,462 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:56:40,468 | 2290543087.py:21 | cid: 1494
# DEBUG flwr 2025-02-06 14:56:41,744 | server_returns_parameters.py:237 | fit_round 18 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 120.72it/s]
# INFO flwr 2025-02-06 14:56:43,022 | server_returns_parameters.py:120 | fit progress: (18, 352.96165227890015, {'accuracy': 0.0715625}, 48.405158834008034)
# INFO flwr 2025-02-06 14:56:43,022 | server_returns_parameters.py:171 | evaluate_round 18: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:56:43,023 | server_returns_parameters.py:223 | fit_round 19: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:56:43,025 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:56:43,025 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-06 14:56:43,025 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:56:43,027 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:56:43,030 | 2290543087.py:21 | cid: 2338
# DEBUG flwr 2025-02-06 14:56:44,439 | server_returns_parameters.py:237 | fit_round 19 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 119.13it/s]
# INFO flwr 2025-02-06 14:56:45,718 | server_returns_parameters.py:120 | fit progress: (19, 358.60454988479614, {'accuracy': 0.074375}, 51.10176866700931)
# INFO flwr 2025-02-06 14:56:45,719 | server_returns_parameters.py:171 | evaluate_round 19: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:56:45,720 | server_returns_parameters.py:223 | fit_round 20: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:56:45,721 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-06 14:56:45,723 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:56:45,724 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:56:45,725 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-06 14:56:45,727 | 2290543087.py:21 | cid: 2399
# DEBUG flwr 2025-02-06 14:56:47,166 | server_returns_parameters.py:237 | fit_round 20 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 120.22it/s]
# INFO flwr 2025-02-06 14:56:48,428 | server_returns_parameters.py:120 | fit progress: (20, 364.7353091239929, {'accuracy': 0.074375}, 53.811691334005445)
# INFO flwr 2025-02-06 14:56:48,429 | server_returns_parameters.py:171 | evaluate_round 20: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:56:48,430 | server_returns_parameters.py:223 | fit_round 21: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:56:48,431 | 2290543087.py:21 | cid: 678
# INFO flwr 2025-02-06 14:56:48,432 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-06 14:56:48,434 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:56:48,436 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:56:48,438 | 2290543087.py:21 | cid: 1260
# DEBUG flwr 2025-02-06 14:56:49,952 | server_returns_parameters.py:237 | fit_round 21 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 120.63it/s]
# INFO flwr 2025-02-06 14:56:51,214 | server_returns_parameters.py:120 | fit progress: (21, 363.0780417919159, {'accuracy': 0.0740625}, 56.59771412500413)
# INFO flwr 2025-02-06 14:56:51,215 | server_returns_parameters.py:171 | evaluate_round 21: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:56:51,216 | server_returns_parameters.py:223 | fit_round 22: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:56:51,217 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 14:56:51,217 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-06 14:56:51,218 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-06 14:56:51,221 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-06 14:56:51,221 | 2290543087.py:21 | cid: 2530
# DEBUG flwr 2025-02-06 14:56:52,698 | server_returns_parameters.py:237 | fit_round 22 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 120.97it/s]
# INFO flwr 2025-02-06 14:56:53,967 | server_returns_parameters.py:120 | fit progress: (22, 362.2531831264496, {'accuracy': 0.074375}, 59.35088158400322)
# INFO flwr 2025-02-06 14:56:53,968 | server_returns_parameters.py:171 | evaluate_round 22: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:56:53,969 | server_returns_parameters.py:223 | fit_round 23: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:56:53,970 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:56:53,972 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:56:53,972 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:56:53,975 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-06 14:56:53,978 | 2290543087.py:21 | cid: 1571
# DEBUG flwr 2025-02-06 14:56:55,510 | server_returns_parameters.py:237 | fit_round 23 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06,
strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:57:58,105 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-06 14:57:58,106 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-06 14:57:58,108 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:57:58,109 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:57:58,112 | 2290543087.py:21 | cid: 1473
# DEBUG flwr 2025-02-06 14:57:59,580 | server_returns_parameters.py:237 | fit_round 47 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 114.91it/s]
# INFO flwr 2025-02-06 14:58:00,847 | server_returns_parameters.py:120 | fit progress: (47, 356.88720202445984, {'accuracy': 0.074375}, 126.23211445900961)
# INFO flwr 2025-02-06 14:58:00,847 | server_returns_parameters.py:171 | evaluate_round 47: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:58:00,848 | server_returns_parameters.py:223 | fit_round 48: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:58:00,849 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-06 14:58:00,850 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 14:58:00,859 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-06 14:58:00,860 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:58:00,870 | 2290543087.py:21 | cid: 2688
# DEBUG flwr 2025-02-06 14:58:02,236 | server_returns_parameters.py:237 | fit_round 48 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 105.25it/s]
# INFO flwr 2025-02-06 14:58:03,614 | server_returns_parameters.py:120 | fit progress: (48, 356.8063657283783, {'accuracy': 0.074375}, 128.99923400000262)
# INFO flwr 2025-02-06 14:58:03,614 | server_returns_parameters.py:171 | evaluate_round 48: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:58:03,615 | server_returns_parameters.py:223 | fit_round 49: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:58:03,617 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:58:03,617 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-06 14:58:03,620 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:58:03,623 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:58:03,624 | 2290543087.py:21 | cid: 2688
# DEBUG flwr 2025-02-06 14:58:05,174 | server_returns_parameters.py:237 | fit_round 49 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 118.39it/s]
# INFO flwr 2025-02-06 14:58:06,418 | server_returns_parameters.py:120 | fit progress: (49, 356.77606558799744, {'accuracy': 0.0640625}, 131.80295925000974)
# INFO flwr 2025-02-06 14:58:06,418 | server_returns_parameters.py:171 | evaluate_round 49: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:58:06,419 | server_returns_parameters.py:223 | fit_round 50: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:58:06,420 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:58:06,422 | 2290543087.py:21 | cid: 839
# INFO flwr 2025-02-06 14:58:06,422 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 14:58:06,426 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:58:06,435 | 2290543087.py:21 | cid: 678
# DEBUG flwr 2025-02-06 14:58:08,025 | server_returns_parameters.py:237 | fit_round 50 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 116.83it/s]
# INFO flwr 2025-02-06 14:58:09,282 | server_returns_parameters.py:120 | fit progress: (50, 357.46773648262024, {'accuracy': 0.070625}, 134.6671317500004)
# INFO flwr 2025-02-06 14:58:09,282 | server_returns_parameters.py:171 | evaluate_round 50: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:58:09,283 | server_returns_parameters.py:223 | fit_round 51: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:58:09,284 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02
| 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:59:11,633 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-06 14:59:11,636 | 2290543087.py:21 | cid: 1260
# DEBUG flwr 2025-02-06 14:59:13,148 | server_returns_parameters.py:237 | fit_round 73 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 124.96it/s]
# INFO flwr 2025-02-06 14:59:14,345 | server_returns_parameters.py:120 | fit progress: (73, 360.30965399742126, {'accuracy': 0.069375}, 199.73232758400263)
# INFO flwr 2025-02-06 14:59:14,345 | server_returns_parameters.py:171 | evaluate_round 73: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:59:14,346 | server_returns_parameters.py:223 | fit_round 74: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:59:14,347 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-06 14:59:14,348 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:59:14,350 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-06 14:59:14,355 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 14:59:14,355 | 2290543087.py:21 | cid: 1473
# DEBUG flwr 2025-02-06 14:59:15,681 | server_returns_parameters.py:237 | fit_round 74 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 125.58it/s]
# INFO flwr 2025-02-06 14:59:16,892 | server_returns_parameters.py:120 | fit progress: (74, 360.26784563064575, {'accuracy': 0.069375}, 202.27989637501014)
# INFO flwr 2025-02-06 14:59:16,893 | server_returns_parameters.py:171 | evaluate_round 74: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:59:16,894 | server_returns_parameters.py:223 | fit_round 75: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:59:16,895 | 2290543087.py:21 | cid: 839
# INFO flwr 2025-02-06 14:59:16,896 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-06 14:59:16,898 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-06 14:59:16,900 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-06 14:59:16,901 | 2290543087.py:21 | cid: 2997
# DEBUG flwr 2025-02-06 14:59:18,220 | server_returns_parameters.py:237 | fit_round 75 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 126.49it/s]
# INFO flwr 2025-02-06 14:59:19,407 | server_returns_parameters.py:120 | fit progress: (75, 359.4993369579315, {'accuracy': 0.079375}, 204.79431737501)
# INFO flwr 2025-02-06 14:59:19,407 | server_returns_parameters.py:171 | evaluate_round 75: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:59:19,408 | server_returns_parameters.py:223 | fit_round 76: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:59:19,409 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:59:19,410 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:59:19,414 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-06 14:59:19,421 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-06 14:59:19,422 | 2290543087.py:21 | cid: 2855
# DEBUG flwr 2025-02-06 14:59:20,761 | server_returns_parameters.py:237 | fit_round 76 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 119.71it/s]
# INFO flwr 2025-02-06 14:59:21,996 | server_returns_parameters.py:120 | fit progress: (76, 358.66088676452637, {'accuracy': 0.079375}, 207.38343479200557)
# INFO flwr 2025-02-06 14:59:21,996 | server_returns_parameters.py:171 | evaluate_round 76: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:59:21,997 | server_returns_parameters.py:223 | fit_round 77: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:59:21,998 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:59:22,001 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-06 14:59:22,001 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-06 14:59:22,003 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-06 14:59:22,006 | 2290543087.py:21 | cid: 1473
# DEBUG flwr 2025-02-06 14:59:23,282 | server_returns_parameters.py:237 | fit_round 77 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 123.00it/s]
# INFO flwr 2025-02-06 14:59:24,491 | server_returns_parameters.py:120 | fit progress: (77, 358.7787103652954, {'accuracy': 0.079375}, 209.87841562500398)
# INFO flwr 2025-02-06 14:59:24,491 | server_returns_parameters.py:171 | evaluate_round 77: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:59:24,492 | server_returns_parameters.py:223 | fit_round 78: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:59:24,493 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-06 14:59:24,494 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:59:24,496 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 14:59:24,499 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-06 14:59:24,501 | 2290543087.py:21 | cid: 3175
# DEBUG flwr 2025-02-06 14:59:25,819 | server_returns_parameters.py:237 | fit_round 78 received 5 results and 0 failures
#  11%|█         | 100/891 [00:01<00:08, 94.10it/s]
# INFO flwr 2025-02-06 14:59:27,354 | server_returns_parameters.py:120 | fit progress: (78, 358.93763494491577, {'accuracy': 0.079375}, 212.74186529200233)
# INFO flwr 2025-02-06 14:59:27,355 | server_returns_parameters.py:171 | evaluate_round 78: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:59:27,355 | server_returns_parameters.py:223 | fit_round 79: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:59:27,356 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-06 14:59:27,358 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-06 14:59:27,360 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-06 14:59:27,362 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-06 14:59:27,362 | 2290543087.py:21 | cid: 839
# DEBUG flwr 2025-02-06 14:59:28,901 | server_returns_parameters.py:237 | fit_round 79 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 116.54it/s]
# INFO flwr 2025-02-06 14:59:30,194 | server_returns_parameters.py:120 | fit progress: (79, 359.0339677333832, {'accuracy': 0.079375}, 215.58207141701132)
# INFO flwr 2025-02-06 14:59:30,195 | server_returns_parameters.py:171 | evaluate_round 79: no clients selected, cancel
# DEBUG flwr 2025-02-06 14:59:30,195 | server_returns_parameters.py:223 | fit_round 80: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-06 14:59:30,197 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-06 14:59:30,199 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-06 14:59:30,201 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-06 14:59:30,209 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-06 14:59:30,213 | 2290543087.py:21 | cid: 2600
# DEBUG flwr 2025-02-06 14:59:31,610 | server_returns_parameters.py:237 | fit_round 80 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 108.70it/s]
# INFO flwr 2025-02-06 14:59:32,959 | server_returns_parameters.py:120 | fit progress: (80, 359.4545679092407, {'accuracy': 0.070625}, 218.34732066700235)
), (58, 357.55705857276917), (59, 358.23255372047424), (60, 358.1234350204468), (61, 358.17911195755005), (62, 358.38158988952637), (63, 358.9070224761963), (64, 359.1856095790863), (65, 359.28762698173523), (66, 359.1205372810364), (67, 359.10618567466736), (68, 359.64371156692505), (69, 360.17763018608093), (70, 360.0155258178711), (71, 360.14456510543823), (72, 359.9431059360504), (73, 360.30965399742126), (74, 360.26784563064575), (75, 359.4993369579315), (76, 358.66088676452637), (77, 358.7787103652954), (78, 358.93763494491577), (79, 359.0339677333832), (80, 359.4545679092407)]
# INFO flwr 2025-02-06 14:59:32,963 | app.py:254 | app_fit: metrics_centralized {'accuracy': [(0, 0.0065625), (1, 0.074375), (2, 0.070625), (3, 0.079375), (4, 0.05625), (5, 0.074375), (6, 0.16), (7, 0.184375), (8, 0.1828125), (9, 0.2053125), (10, 0.113125), (11, 0.115625), (12, 0.1690625), (13, 0.19125), (14, 0.1725), (15, 0.1853125), (16, 0.125), (17, 0.11625), (18, 0.0715625), (19, 0.074375), (20, 0.074375), (21, 0.0740625), (22, 0.074375), (23, 0.074375), (24, 0.069375), (25, 0.069375), (26, 0.069375), (27, 0.0709375), (28, 0.070625), (29, 0.070625), (30, 0.070625), (31, 0.079375), (32, 0.079375), (33, 0.074375), (34, 0.074375), (35, 0.074375), (36, 0.074375), (37, 0.069375), (38, 0.070625), (39, 0.070625), (40, 0.070625), (41, 0.070625), (42, 0.079375), (43, 0.079375), (44, 0.079375), (45, 0.079375), (46, 0.074375), (47, 0.074375), (48, 0.074375), (49, 0.0640625), (50, 0.070625), (51, 0.079375), (52, 0.079375), (53, 0.079375), (54, 0.079375), (55, 0.079375), (56, 0.074375), (57, 0.074375), (58, 0.074375), (59, 0.074375), (60, 0.079375), (61, 0.079375), (62, 0.079375), (63, 0.079375), (64, 0.071875), (65, 0.079375), (66, 0.079375), (67, 0.079375), (68, 0.070625), (69, 0.070625), (70, 0.070625), (71, 0.070625), (72, 0.069375), (73, 0.069375), (74, 0.069375), (75, 0.079375), (76, 0.079375), (77, 0.079375), (78, 0.079375), (79, 0.079375), (80, 0.070625)]}
# INFO flwr 2025-02-06 14:59:32,999 | 3085244168.py:7 | Size of the list with the model parameters: 81

# %%
ideal_params = flatten_params(parameters_for_each_round[-1][1])

cos_similarities = [
    cosine_similarity(
        flatten_params(parameters_for_each_round[r+1][1]) - flatten_params(parameters_for_each_round[r][1]),
        ideal_params - flatten_params(parameters_for_each_round[r][1])
    )
    for r, _ in parameters_for_each_round[:-1]
]

# %%
n_rounds = len(parameters_for_each_round)
plt.plot(range(n_rounds - 1), cos_similarities)
plt.xlabel('Round Number')
plt.ylabel('Cosine Similarity')
plt.title('Similarity between the pseudo-gradient $g_t$ and the direction of improvement with momentum')
plt.grid(True)
plt.show()

# %% [markdown]
# We can see that the momentum helps the gradient break the stagnating period. Server momentum is a technique that takes into account previous gradient values of the server to update the current gradient. This way, model can more easily break out of situations like local minima.

# %% [markdown]
# (c) 2024 Alexandru-Andrei Iacob, Lorenzo Sani
